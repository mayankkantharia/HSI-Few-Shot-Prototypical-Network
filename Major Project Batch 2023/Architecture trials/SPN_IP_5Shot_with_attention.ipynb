# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install spectral
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spectral
#   Downloading spectral-0.23.1-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 KB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from spectral) (1.22.4)
# Installing collected packages: spectral
# Successfully installed spectral-0.23.1

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import random
from tensorflow.keras import Sequential,layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import statistics
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score
import tensorflow_probability as tfp
from operator import truediv
from tensorflow.compat.v1.distributions import Bernoulli
from plotly.offline import init_notebook_mode

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import os
import spectral
import tensorflow as tf
from tensorflow.python.keras import backend as K

init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Global variables
im_width, im_height, im_depth, im_channel = 11,11,30, 1
mc_loss_weight = 5

# %% [markdown]
# ## Model Construction

# %%
def calc_euclidian_dists(x, y):
  # x : (n,d)
  # y : (m,d)
    n = x.shape[0]
    m = y.shape[0]
    x = tf.tile(tf.expand_dims(x, 1), [1, m, 1])
    y = tf.tile(tf.expand_dims(y, 0), [n, 1, 1])
    return tf.reduce_mean(tf.math.pow(x - y, 2), 2)

# %%
def _bernoulli(shape, mean):
    return tf.nn.relu(tf.sign(mean - tf.random.uniform(shape, minval=0, maxval=1, dtype=tf.float32)))

# %%
class DropBlock3D(tf.keras.layers.Layer):
    def __init__(self, keep_prob, block_size, scale=True, **kwargs):
        super(DropBlock3D, self).__init__(**kwargs)
        self.keep_prob = float(keep_prob) if isinstance(keep_prob, int) else keep_prob
        self.block_size = int(block_size)
        self.scale = tf.constant(scale, dtype=tf.bool) if isinstance(scale, bool) else scale

    def compute_output_shape(self, input_shape):
        return input_shape

    def build(self, input_shape):
        assert len(input_shape) == 5
        _, self.d, self.h, self.w, self.channel = input_shape.as_list()
        # pad the mask
        p0 = (self.block_size - 1) // 2
        p1 = (self.block_size - 1) - p0
        self.padding = [[0, 0], [p0, p1], [p0, p1], [p0, p1], [0, 0]]
        self.set_keep_prob()
        super(DropBlock3D, self).build(input_shape)

    def call(self, inputs, training=True, **kwargs):
        def drop():
            mask = self._create_mask(tf.shape(inputs))
            output = inputs * mask
            output = tf.cond(self.scale,
                             true_fn=lambda: output * tf.compat.v1.to_float(tf.size(mask)) / tf.reduce_sum(mask),
                             false_fn=lambda: output)
            return output

        if training is None:
            training = K.learning_phase()
        output = tf.cond(tf.logical_or(tf.logical_not(training), tf.equal(self.keep_prob, 1.0)),
                         true_fn=lambda: inputs,
                         false_fn=drop)
        return output

    def set_keep_prob(self, keep_prob=None):
        """This method only supports Eager Execution"""
        if keep_prob is not None:
            self.keep_prob = keep_prob
        d, w, h = tf.compat.v1.to_float(self.d), tf.compat.v1.to_float(self.w), tf.compat.v1.to_float(self.h)
        self.gamma = ((1. - self.keep_prob) * (d * w * h) / (self.block_size ** 3) /
                      ((d - self.block_size + 1) * (w - self.block_size + 1) * (h - self.block_size + 1)))

    def _create_mask(self, input_shape):
        sampling_mask_shape = tf.stack([input_shape[0],
                                        self.d - self.block_size + 1,
                                        self.h - self.block_size + 1,
                                        self.w - self.block_size + 1,
                                        self.channel])
        mask = _bernoulli(sampling_mask_shape, self.gamma)
        mask = tf.pad(mask, self.padding)
        mask = tf.nn.max_pool3d(mask, [1, self.block_size, self.block_size, self.block_size, 1], [1, 1, 1, 1, 1], 'SAME')
        mask = 1 - mask
        return mask

# %%
# input_layer = layers.Input(shape = (im_height, im_width, im_depth, im_channel))
# out1 = layers.Conv3D(filters=8, kernel_size=(3,3,7), activation='relu',input_shape=(im_height, im_width, im_depth, im_channel),padding='same')(input_layer)
# out1 = DropBlock3D(0.7,3)(out1)
# out2 = layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu',padding='same')(out1)
# out2 = DropBlock3D(0.7,3)(out2)
# out3 = layers.Conv3D(filters=32, kernel_size=(3,3,3), activation= 'relu')(out2)
# out3 = layers.Reshape((out3.shape[1], out3.shape[2], out3.shape[3]*out3.shape[4]))(out3)
# out3 = layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(out3)
# out4 = layers.Flatten()(out3)
# out4 = layers.Dropout(0.4)(out4, training=True)
# out4 = layers.Dense(256, activation='relu')(out4)
# out5 = layers.Dropout(0.4)(out4,training=True)
# out5 = layers.Dense(128, activation='relu')(out5)

# #out5 = layers.Dropout(0.4)(out5, training=True)
# #out6 = layers.Dense(16, activation='relu')(out5)
# model = Model(inputs=input_layer,outputs=out5)
# model.summary()

# %%
# input_layer = layers.Input(shape = (im_height, im_width, im_depth, im_channel))
# out1 = layers.Conv3D(filters=8, kernel_size=(3,3,7), activation='relu',input_shape=(im_height, im_width, im_depth, im_channel),padding='same')(input_layer)
# out1 = DropBlock3D(0.7,3)(out1)
# out2 = layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu',padding='same')(out1)
# out2 = DropBlock3D(0.7,3)(out2)
# out3 = layers.Conv3D(filters=32, kernel_size=(3,3,3), activation= 'relu')(out2)
# out3 = layers.Reshape((out3.shape[1], out3.shape[2], out3.shape[3]*out3.shape[4]))(out3)
# out4 = layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(out3)

# # Use out4 as both query and value tensors
# # Use input_layer as the key tensor
# # The output shape will be [batch_size, out4.shape[1], out4.shape[2], out4.shape[3]]
# attention_output = layers.Attention()([out4, input_layer])

# # Flatten the attention output and add dropout and dense layers as before
# out5 = layers.Flatten()(attention_output)
# out5 = layers.Dropout(0.4)(out5, training=True)
# out5 = layers.Dense(256, activation='relu')(out5)
# out6 = layers.Dropout(0.4)(out5,training=True)
# out6 = layers.Dense(128, activation='relu')(out6)

# model = Model(inputs=input_layer,outputs=out6)
# model.summary()

# %%
# ## new code not good
# input_layer = layers.Input(shape = (im_height, im_width, im_depth, im_channel))
# out1 = layers.Conv3D(filters=8, kernel_size=(3,3,7), activation='relu',input_shape=(im_height, im_width, im_depth, im_channel),padding='same')(input_layer)
# out1 = DropBlock3D(0.7,3)(out1)
# out2 = layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu',padding='same')(out1)
# out2 = DropBlock3D(0.7,3)(out2)
# out3 = layers.Conv3D(filters=32, kernel_size=(3,3,3), activation= 'relu')(out2)
# out3 = layers.Reshape((out3.shape[1], out3.shape[2], out3.shape[3]*out3.shape[4]))(out3)
# out3 = layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(out3)
# out4 = layers.Flatten()(out3)
# out4 = layers.Dropout(0.4)(out4, training=True)
# out4 = layers.Dense(256, activation='relu')(out4)
# out5 = layers.Dropout(0.4)(out4,training=True)
# out5 = layers.Dense(128, activation='relu')(out5)
# attention = layers.Attention()([out5, out5])
# out6 = layers.Concatenate()([out5, attention])
# out6 = layers.Dense(128, activation='relu')(out6)
# model = Model(inputs=input_layer, outputs=out6)
# model.summary()

# %%
input_layer = layers.Input(shape = (im_height, im_width, im_depth, im_channel))
out1 = layers.Conv3D(filters=8, kernel_size=(3,3,7), activation='relu',input_shape=(im_height, im_width, im_depth, im_channel),padding='same')(input_layer)
out1 = DropBlock3D(0.7,3)(out1)
out2 = layers.Conv3D(filters=16, kernel_size=(3,3,5), activation='relu',padding='same')(out1)
out2 = DropBlock3D(0.7,3)(out2)
out3_conv = layers.Conv3D(filters=32, kernel_size=(3,3,3), activation= 'relu', padding = 'same')(out2)
out3 = DropBlock3D(0.7,3)(out3_conv)
attention = layers.Attention()([out3, out3_conv])
out3 = layers.Reshape((out3.shape[1], out3.shape[2], out3.shape[3]*out3.shape[4]))(attention)
out3 = layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(out3)
out4 = layers.Flatten()(out3)
out4 = layers.Dropout(0.4)(out4, training=True)
out4 = layers.Dense(256, activation='relu')(out4)
out5 = layers.Dropout(0.4)(out4,training=True)
out5 = layers.Dense(128, activation='relu')(out5)
model = Model(inputs=input_layer, outputs=out5)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 11, 11, 30,  0           []
#                                  1)]
#
#  conv3d (Conv3D)                (None, 11, 11, 30,   512         ['input_1[0][0]']
#                                 8)
#
#  drop_block3d (DropBlock3D)     (None, 11, 11, 30,   0           ['conv3d[0][0]']
#                                 8)
#
#  conv3d_1 (Conv3D)              (None, 11, 11, 30,   5776        ['drop_block3d[0][0]']
#                                 16)
#
#  drop_block3d_1 (DropBlock3D)   (None, 11, 11, 30,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 11, 11, 30,   13856       ['drop_block3d_1[0][0]']
#                                 32)
#
#  drop_block3d_2 (DropBlock3D)   (None, 11, 11, 30,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  attention (Attention)          (None, 11, 11, 30,   0           ['drop_block3d_2[0][0]',
#                                 32)                               'conv3d_2[0][0]']
#
#  reshape (Reshape)              (None, 11, 11, 960)  0           ['attention[0][0]']
#
#  conv2d (Conv2D)                (None, 9, 9, 64)     553024      ['reshape[0][0]']
#
#  flatten (Flatten)              (None, 5184)         0           ['conv2d[0][0]']
#
#  dropout (Dropout)              (None, 5184)         0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 256)          1327360     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1,933,424
# Trainable params: 1,933,424
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class Prototypical(Model):
    def __init__(self, model, w, h, d, c):
        super(Prototypical, self).__init__()
        self.w, self.h, self.d, self.c = w, h, d, c
        self.encoder = model

    def call(self, support, query, support_labels, query_labels, K, C, N,n_times,training=True):
      n_class = C                                                               #10
      n_support = K                                                             #5
      n_query = N                                                               #15 
      temperature = 1.9

      if training == True : 
        loss = 0
        mc_predictions = []                                                     # list of predictions for multiple passes
        for i in range(n_times) :
          y = np.zeros((int(C*N),C))                                            #(150,10)
          for i in range(int(C*N)) :
            x = support_labels.index(query_labels[i])                           # creation of 1-hot for true labels
            y[i][x] = 1.                                                        # n_times passing every query image for calculating variance 
          cat = tf.concat([support,query], axis=0)                              # [200,9,9,20,1])   
          z = self.encoder(cat)                                                 # [200, 320]
          # Divide embedding into support and query
          z_prototypes = tf.reshape(z[:n_class * n_support],[n_class, n_support, z.shape[-1]])   #[10, 5, 320])
          # Prototypes are means of n_support examples
          z_prototypes = tf.math.reduce_mean(z_prototypes, axis=1)              #[10, 320]
          z_query = z[n_class * n_support:]                                     #[150, 320]                         
          # Calculate distances between query and prototypes
          dists = calc_euclidian_dists(z_query, z_prototypes)                   #[150, 10]
          # log softmax of calculated distances
          log_p_y = tf.nn.log_softmax(-dists, axis=-1)                          #[150, 10]        
          loss1 = -tf.reduce_mean((tf.reduce_sum(tf.multiply(y, log_p_y), axis=-1)))   #loss for the current pass                     
          loss += loss1                                                         # adding loss for each pass                   
          softmax_predictions = tf.nn.softmax(-dists, axis=-1)                  # prediction probability for the search-space classes per query image(for current pass)
          new_distance = dists/temperature                                      # T = 1.1 to 3.0 for Temperature Scaling
          predictions = tf.nn.softmax(-new_distance, axis=-1)                   # prediction probability with temperature scaling        
          # print('Loop Number :', i)
          # print("A" * 10) 
          # print("Dists : ", dists[0])
          # print("B" * 10)           
          # print('New Distance (T applied): ', new_distance[0])
          # print("C" * 10)
          # print("Softmax Predictions : ", softmax_predictions[0])
          # print("D" * 10)
          # print("Temperature Scaling Predictions : ", predictions[0])
          # print()
          mc_predictions.append(predictions)                                        
        y = np.zeros((int(C*N),C))
        for i in range(int(C*N)) :
            x = support_labels.index(query_labels[i])                           # creation of 1-hot for true labels
            y[i][x] = 1. 
        mc_predictions = tf.convert_to_tensor(np.reshape(np.asarray(mc_predictions),(n_times,int(C*N),C)))  #(n_times,150,10)
        std_predictions = tf.math.reduce_std(mc_predictions,axis=0)
        std = tf.reduce_sum(tf.reduce_sum(tf.multiply(std_predictions,y),axis=1))
        # print('std', std)        
        loss += mc_loss_weight*std
        temp_list.append(std)
        # calculating mean accuracy
        mean_predictions = tf.reduce_mean(mc_predictions,axis=0)                # mean prediction probability for each class (150,10)
        mean_eq = tf.cast(tf.equal(                                             # accuracy for the current pass
            tf.cast(tf.argmax(mean_predictions, axis=-1), tf.int32), 
            tf.cast(tf.argmax(y,axis=-1), tf.int32)), tf.float32)
        mean_accuracy = tf.reduce_mean(mean_eq)
        mean_predictions = tf.reduce_mean(mc_predictions,axis=0)                # mean prediction probability for each class (150,10)
        return loss, mean_accuracy, mean_predictions   
      if training == False :
        loss = 0
        mc_predictions = []                                                     # list of predictions for multiple passes  
        for i in range(n_times) :                                               # n_times passing the query images for variance calculation
          y = np.zeros((int(C*N),C))                                            # (150,10)
          for i in range(int(C*N)) :
            x = support_labels.index(query_labels[i])                           # creation of 1-hot for the true labels
            y[i][x] = 1.  
          # merge support and query to forward through encoder
          cat = tf.concat([support,query], axis=0)                              # [200,9,9,20,1]   
          z = self.encoder(cat)                                                 # [200, 320]
          # Divide embedding into support and query
          z_prototypes = tf.reshape(z[:n_class * n_support],[n_class, n_support, z.shape[-1]])   #[10, 5, 320])
          # Prototypes are means of n_support examples
          z_prototypes = tf.math.reduce_mean(z_prototypes, axis=1)              #[10, 320]
          z_query = z[n_class * n_support:]                                     #[150, 320]                         
          # Calculate distances between query and prototypes
          dists = calc_euclidian_dists(z_query, z_prototypes)                   #[150, 10]
          # log softmax of calculated distances
          log_p_y = tf.nn.log_softmax(-dists, axis=-1)                          #[150, 10]        
          loss1 = -tf.reduce_mean((tf.reduce_sum(tf.multiply(y, log_p_y), axis=-1)))        
          loss += loss1
          softmax_predictions = tf.nn.softmax(-dists, axis=-1)                  # prediction probability for the search-space classes per query image(for current pass)
          new_distance = dists/temperature                                      # T = 1.1 to 3.0 for Temperature Scaling
          predictions = tf.nn.softmax(-new_distance, axis=-1)                   # prediction probability with temperature scaling        
          # print('Loop Number : ', i)
          # print("A" * 10) 
          # print("Dists : ", dists[0])
          # print("B" * 10)           
          # print('New Distance (T applied): ', new_distance[0])
          # print("C" * 10)
          # print("Softmax Predictions : ", softmax_predictions[0])
          # print("D" * 10)
          # print("Temperature Scaling Predictions : ", predictions[0])
          mc_predictions.append(predictions)                                             
        y = np.zeros((int(C*N),C))                                            # (150,10)
        for i in range(int(C*N)) :
            x = support_labels.index(query_labels[i])                           # creation of 1-hot for the true labels
            y[i][x] = 1.  
        mean_predictions = tf.reduce_mean(mc_predictions,axis=0)                # mean prediction probability for each class (150,10)
        mean_eq = tf.cast(tf.equal(                                             # accuracy for the current pass
            tf.cast(tf.argmax(mean_predictions, axis=-1), tf.int32), 
            tf.cast(tf.argmax(y,axis=-1), tf.int32)), tf.float32)
        mean_accuracy = tf.reduce_mean(mean_eq)
        mean_pred_index = tf.argmax(mean_predictions,axis=1)
        # mean class-wise accuracies
        mean_correct_class = [[] for i in range(tC)]
        mean_correct_pred = [[] for i in range(tC)]
        classwise_mean_acc = [[] for i in range(tC)]
        for i in range(int(C*N)):
          x = support_labels.index(query_labels[i])
          mean_correct_class[x].append('4')
          if(mean_pred_index[i] == x) :
            mean_correct_pred[x].append('4')
        for i in range(tC) :
           z = len(mean_correct_pred[i])/len(mean_correct_class[i])
           classwise_mean_acc[i].append(z)  
        #std calculation
        std = 0
        for i in range(int(C*N)) :
           x = support_labels.index(query_labels[i])
           p_i = np.array([p[i,:] for p in mc_predictions])
           std_i = tf.math.reduce_std(p_i,axis=0) 
           std_i_true = std_i[x]
           std += std_i_true                                                    # adding std of each class
        # print('std',std)
        loss += mc_loss_weight*std 
        y = np.zeros((int(C*N),C))                                            # (150,10)
        for i in range(int(C*N)) :
            x = support_labels.index(query_labels[i])                           # creation of 1-hot for the true labels
            y[i][x] = 1.                                                                
        return loss, mc_predictions, mean_accuracy, classwise_mean_acc, y


      def save(self, model_path):
        self.encoder.save(model_path)

      def load(self, model_path):
        self.encoder(tf.zeros([1, self.w, self.h, self.c]))
        self.encoder.load_weights(model_path)

# %% [markdown]
# ## Data Loading

# %%
def loadData(name):
    data = sio.loadmat('/content/drive/My Drive/Data/indian_pines_corrected.mat')['indian_pines_corrected']
    labels = sio.loadmat('/content/drive/My Drive/Data/indian_pines_gt.mat')['indian_pines_gt']
    return data, labels
# without reduction of 200 channels to 30 channels, memory error while creating cube 
def applyPCA(X, numComponents):
    newX = np.reshape(X, (-1, X.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, pca

def padWithZeros(X, margin):
    newX = np.zeros((X.shape[0] + 2 * margin, X.shape[1] + 2* margin, X.shape[2]))
    x_offset = margin
    y_offset = margin
    newX[x_offset:X.shape[0] + x_offset, y_offset:X.shape[1] + y_offset, :] = X
    return newX

def createImageCubes(X, y, windowSize, removeZeroLabels = True):
    margin = int((windowSize - 1) / 2)
    zeroPaddedX = padWithZeros(X, margin=margin)  # X :(145, 145, 30) --> (195, 195, 30) with window =25
    # split patches
    patchesData = np.zeros((X.shape[0] * X.shape[1], windowSize, windowSize, X.shape[2]))  # (21025, 25, 25, 30)   
    patchesLabels = np.zeros((X.shape[0] * X.shape[1]))  # (21025,)
    patchIndex = 0
    
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1, c - margin:c + margin + 1]  
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = y[r-margin, c-margin]            
            patchIndex = patchIndex + 1
  
    patchesData = np.expand_dims(patchesData, axis=-1)
    return patchesData,patchesLabels

# %%
dataset1 = 'indian_pines'                                         # 16 classes   
ip_x1, ip_y = loadData(dataset1)                              #((512, 217, 204), (512, 217))
ip_x2,pca = applyPCA(ip_x1,numComponents=30)                   # ((512, 217, 20), (512, 217))
ip_X,ip_Y = createImageCubes(ip_x2, ip_y, windowSize=11)   #(111104, 9, 9, 20, 1) (111104,)
print(ip_X.shape,ip_Y.shape)
# Out:
# (21025, 11, 11, 30, 1) (21025,)

# %%
def patches_class(X,Y,n) :
  n_classes = n
  patches_list = []
  for i in range(1,n_classes+1):   # not considering class 0
    patchesData_Ith_Label = X[Y==i,:,:,:,:]
    patches_list.append(patchesData_Ith_Label)
  return patches_list

# %%
patches_class_ip = patches_class(ip_X,ip_Y,16) # class_wise list of patches #(16,) for class 0: (2009, 9, 9, 20, 1)

# %%
train_class_indices = [1,2,4,5,7,9,10,11,13,14]
test_class_indices = [0,3,6,8,12,15]
train_patches_class = [patches_class_ip[i] for i in train_class_indices]        #(10)
test_patches_class = [patches_class_ip[i] for i in test_class_indices]        #(6) 
train_class_labels = [2,3,5,6,8,10,11,12,14,15]   
test_class_labels = [1,4,7,9,13,16]     #[11...16]

# %% [markdown]
# **Prepare Training and validation Dataset**

# %% [markdown]
# **Create DataLoader**

# %%
C = 5  # n_class
K1 = 5   # n_support
N = 15   # n_query
tC = 3   # classes in a test episode
im_height,im_width,im_depth = 11,11,30

# %%
def new_episode(patches_list,K,C,N,class_labels) :
  selected_classes = np.random.choice(class_labels,C,replace=False)  # Randomly choice 5 Classes out of classes available
  tsupport_patches = []
  tquery_patches = []
  query_labels = []
  support_labels = list(selected_classes)
  for x in selected_classes :
    sran_indices = np.random.choice(len(patches_list[x-1]),K,replace=False)  # for class no X-1: select random sample no
    support_patches = patches_list[x-1][sran_indices,:,:,:,:]
    qran_indices = np.random.choice(len(patches_list[x-1]),N,replace=False)  # N Samples for Query
    query_patches = patches_list[x-1][qran_indices,:,:,:,:]
  # Support and Query patches belong to same Class 
    for i in range(N) :
      query_labels.append(x)    # N Samples for Query
    tquery_patches.extend(query_patches)
    tsupport_patches.extend(support_patches)
  temp1 = list(zip(tquery_patches, query_labels)) 
  random.shuffle(temp1)        # By Doing Shuffling, Support, Query Same class combination got mismatched - mitigated by support index
  tquery_patches, query_labels = zip(*temp1)
  tquery_patches = tf.convert_to_tensor(np.reshape(np.asarray(tquery_patches),(C*N,im_height,im_width,im_depth,1)),dtype=tf.float32)
  tsupport_patches = tf.convert_to_tensor(np.reshape(np.asarray(tsupport_patches),(C*K,im_height,im_width,im_depth,1)),dtype=tf.float32)
  return tquery_patches, tsupport_patches, query_labels, support_labels

# %%
tquery_patches, tsupport_patches, query_labels, support_labels = new_episode(patches_class_ip,K1,C,N,train_class_labels)

# %% [markdown]
# ## Training

# %%
ProtoModel = Prototypical(model,im_width, im_height, im_depth, im_channel)
optimizer = tf.keras.optimizers.Adam(0.00001)          #Adam(0.001)
n_times = 5
#std_list = []

# %%
# Metrics to gather
train_loss = tf.metrics.Mean(name='train_loss')
train_acc = tf.metrics.Mean(name='train_accuracy')

def train_step(support, query, support_labels, query_labels, K, C, N):
    # Forward & update gradients
    with tf.GradientTape() as tape:
        loss, mean_accuracy, mean_predictions = ProtoModel(support, query, support_labels, query_labels, K, C, N,n_times,training=True)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    # Log loss and accuracy for step
    train_loss(loss)
    train_acc(mean_accuracy)

# %%
checkpoint_dir = '/content/drive/My Drive/Research/SAMPLE_CODE_TF2_Keras/Inprogress/Hyperspectral_Classification/Training checkpoints/IP/5_shot_ckpts/New_train_5_way_ip_25_128'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 ProtoModel = ProtoModel)

# %%
n_episodes = 100
temp_list = []
for epoch in range(50): # n_epochs-140
    train_loss.reset_states()  
    train_acc.reset_states()
    
    for epi in range(n_episodes): 
        tquery_patches, tsupport_patches, query_labels, support_labels = new_episode(patches_class_ip,K1,C,N,train_class_labels)     
        train_step(tsupport_patches, tquery_patches,support_labels, query_labels, K1, C, N)    
        template = 'Epoch {}, Episode {}, Train Loss: {:.2f}, Train Accuracy: {:.2f}'
        print(template.format(epoch+1, epi+1,train_loss.result(),train_acc.result()*100))
    if epoch % 5 == 0 and epoch != 0 :
        checkpoint.save(file_prefix = checkpoint_prefix)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f80ccd2baf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f80ccd2baf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1, Episode 1, Train Loss: 8.07, Train Accuracy: 32.00
# Epoch 1, Episode 2, Train Loss: 8.07, Train Accuracy: 30.67
# Epoch 1, Episode 3, Train Loss: 8.07, Train Accuracy: 28.00
# Epoch 1, Episode 4, Train Loss: 8.07, Train Accuracy: 28.33
# Epoch 1, Episode 5, Train Loss: 8.07, Train Accuracy: 27.73
# Epoch 1, Episode 6, Train Loss: 8.07, Train Accuracy: 28.00
# Epoch 1, Episode 7, Train Loss: 8.07, Train Accuracy: 28.19
# Epoch 1, Episode 8, Train Loss: 8.07, Train Accuracy: 30.17
# Epoch 1, Episode 9, Train Loss: 8.07, Train Accuracy: 29.78
# Epoch 1, Episode 10, Train Loss: 8.07, Train Accuracy: 28.67
# Epoch 1, Episode 11, Train Loss: 8.07, Train Accuracy: 27.88
# Epoch 1, Episode 12, Train Loss: 8.08, Train Accuracy: 27.44
# Epoch 1, Episode 13, Train Loss: 8.08, Train Accuracy: 27.28
# Epoch 1, Episode 14, Train Loss: 8.08, Train Accuracy: 26.76
# Epoch 1, Episode 15, Train Loss: 8.08, Train Accuracy: 26.76
# Epoch 1, Episode 16, Train Loss: 8.08, Train Accuracy: 26.92
# Epoch 1, Episode 17, Train Loss: 8.08, Train Accuracy: 27.22
# Epoch 1, Episode 18, Train Loss: 8.08, Train Accuracy: 27.26
# Epoch 1, Episode 19, Train Loss: 8.08, Train Accuracy: 27.44
# Epoch 1, Episode 20, Train Loss: 8.08, Train Accuracy: 27.60
# Epoch 1, Episode 21, Train Loss: 8.09, Train Accuracy: 27.43
# Epoch 1, Episode 22, Train Loss: 8.09, Train Accuracy: 27.09
# Epoch 1, Episode 23, Train Loss: 8.09, Train Accuracy: 27.13
# Epoch 1, Episode 24, Train Loss: 8.09, Train Accuracy: 26.83
# Epoch 1, Episode 25, Train Loss: 8.09, Train Accuracy: 26.99
# Epoch 1, Episode 26, Train Loss: 8.09, Train Accuracy: 26.97
# Epoch 1, Episode 27, Train Loss: 8.09, Train Accuracy: 26.91
# Epoch 1, Episode 28, Train Loss: 8.10, Train Accuracy: 27.10
# Epoch 1, Episode 29, Train Loss: 8.10, Train Accuracy: 27.40
# Epoch 1, Episode 30, Train Loss: 8.10, Train Accuracy: 27.38
# Epoch 1, Episode 31, Train Loss: 8.10, Train Accuracy: 27.14
# Epoch 1, Episode 32, Train Loss: 8.10, Train Accuracy: 27.08
# Epoch 1, Episode 33, Train Loss: 8.11, Train Accuracy: 26.95
# Epoch 1, Episode 34, Train Loss: 8.11, Train Accuracy: 27.22
# Epoch 1, Episode 35, Train Loss: 8.11, Train Accuracy: 27.28
# Epoch 1, Episode 36, Train Loss: 8.11, Train Accuracy: 27.30
# Epoch 1, Episode 37, Train Loss: 8.12, Train Accuracy: 27.60
# Epoch 1, Episode 38, Train Loss: 8.12, Train Accuracy: 27.61
# Epoch 1, Episode 39, Train Loss: 8.12, Train Accuracy: 27.73
# Epoch 1, Episode 40, Train Loss: 8.13, Train Accuracy: 27.87
# Epoch 1, Episode 41, Train Loss: 8.13, Train Accuracy: 27.74
# Epoch 1, Episode 42, Train Loss: 8.13, Train Accuracy: 28.00
# Epoch 1, Episode 43, Train Loss: 8.14, Train Accuracy: 28.09
# Epoch 1, Episode 44, Train Loss: 8.14, Train Accuracy: 28.15
# Epoch 1, Episode 45, Train Loss: 8.14, Train Accuracy: 28.03
# Epoch 1, Episode 46, Train Loss: 8.15, Train Accuracy: 28.06
# Epoch 1, Episode 47, Train Loss: 8.15, Train Accuracy: 28.26
# Epoch 1, Episode 48, Train Loss: 8.16, Train Accuracy: 28.22
# Epoch 1, Episode 49, Train Loss: 8.16, Train Accuracy: 28.00
# Epoch 1, Episode 50, Train Loss: 8.17, Train Accuracy: 27.79
# Epoch 1, Episode 51, Train Loss: 8.18, Train Accuracy: 27.74
# Epoch 1, Episode 52, Train Loss: 8.18, Train Accuracy: 28.05
# Epoch 1, Episode 53, Train Loss: 8.19, Train Accuracy: 28.05
# Epoch 1, Episode 54, Train Loss: 8.20, Train Accuracy: 28.12
# Epoch 1, Episode 55, Train Loss: 8.21, Train Accuracy: 28.19
# Epoch 1, Episode 56, Train Loss: 8.22, Train Accuracy: 28.14
# Epoch 1, Episode 57, Train Loss: 8.22, Train Accuracy: 28.09
# Epoch 1, Episode 58, Train Loss: 8.23, Train Accuracy: 28.09
# Epoch 1, Episode 59, Train Loss: 8.24, Train Accuracy: 28.25
# Epoch 1, Episode 60, Train Loss: 8.25, Train Accuracy: 28.42
# Epoch 1, Episode 61, Train Loss: 8.26, Train Accuracy: 28.39
# Epoch 1, Episode 62, Train Loss: 8.27, Train Accuracy: 28.47
# Epoch 1, Episode 63, Train Loss: 8.29, Train Accuracy: 28.55
# Epoch 1, Episode 64, Train Loss: 8.30, Train Accuracy: 28.46
# Epoch 1, Episode 65, Train Loss: 8.32, Train Accuracy: 28.43
# Epoch 1, Episode 66, Train Loss: 8.33, Train Accuracy: 28.40
# Epoch 1, Episode 67, Train Loss: 8.35, Train Accuracy: 28.38
# Epoch 1, Episode 68, Train Loss: 8.37, Train Accuracy: 28.43
# Epoch 1, Episode 69, Train Loss: 8.39, Train Accuracy: 28.56
# Epoch 1, Episode 70, Train Loss: 8.40, Train Accuracy: 28.51
# Epoch 1, Episode 71, Train Loss: 8.43, Train Accuracy: 28.56
# Epoch 1, Episode 72, Train Loss: 8.45, Train Accuracy: 28.69
# Epoch 1, Episode 73, Train Loss: 8.46, Train Accuracy: 28.60
# Epoch 1, Episode 74, Train Loss: 8.49, Train Accuracy: 28.72
# Epoch 1, Episode 75, Train Loss: 8.51, Train Accuracy: 28.78
# Epoch 1, Episode 76, Train Loss: 8.54, Train Accuracy: 28.81
# Epoch 1, Episode 77, Train Loss: 8.56, Train Accuracy: 29.06
# Epoch 1, Episode 78, Train Loss: 8.61, Train Accuracy: 29.09
# Epoch 1, Episode 79, Train Loss: 8.64, Train Accuracy: 29.18
# Epoch 1, Episode 80, Train Loss: 8.67, Train Accuracy: 29.20
# Epoch 1, Episode 81, Train Loss: 8.72, Train Accuracy: 29.23
# Epoch 1, Episode 82, Train Loss: 8.77, Train Accuracy: 29.27
# Epoch 1, Episode 83, Train Loss: 8.83, Train Accuracy: 29.29
# Epoch 1, Episode 84, Train Loss: 8.89, Train Accuracy: 29.38
# Epoch 1, Episode 85, Train Loss: 8.96, Train Accuracy: 29.41
# Epoch 1, Episode 86, Train Loss: 9.00, Train Accuracy: 29.43
# Epoch 1, Episode 87, Train Loss: 9.07, Train Accuracy: 29.49
# Epoch 1, Episode 88, Train Loss: 9.11, Train Accuracy: 29.52
# Epoch 1, Episode 89, Train Loss: 9.19, Train Accuracy: 29.65
# Epoch 1, Episode 90, Train Loss: 9.28, Train Accuracy: 29.70
# Epoch 1, Episode 91, Train Loss: 9.33, Train Accuracy: 29.77
# Epoch 1, Episode 92, Train Loss: 9.39, Train Accuracy: 29.88
# Epoch 1, Episode 93, Train Loss: 9.48, Train Accuracy: 29.98
# Epoch 1, Episode 94, Train Loss: 9.57, Train Accuracy: 30.16
# Epoch 1, Episode 95, Train Loss: 9.64, Train Accuracy: 30.19
# Epoch 1, Episode 96, Train Loss: 9.76, Train Accuracy: 30.29
# Epoch 1, Episode 97, Train Loss: 9.89, Train Accuracy: 30.38
# Epoch 1, Episode 98, Train Loss: 9.96, Train Accuracy: 30.31
# Epoch 1, Episode 99, Train Loss: 10.05, Train Accuracy: 30.42
# Epoch 1, Episode 100, Train Loss: 10.15, Train Accuracy: 30.37
# Epoch 2, Episode 1, Train Loss: 17.22, Train Accuracy: 24.00
# Epoch 2, Episode 2, Train Loss: 16.51, Train Accuracy: 24.00
# Epoch 2, Episode 3, Train Loss: 19.01, Train Accuracy: 29.78
# Epoch 2, Episode 4, Train Loss: 18.74, Train Accuracy: 31.00
# Epoch 2, Episode 5, Train Loss: 19.55, Train Accuracy: 32.53
# Epoch 2, Episode 6, Train Loss: 19.19, Train Accuracy: 31.78
# Epoch 2, Episode 7, Train Loss: 18.62, Train Accuracy: 31.43
# Epoch 2, Episode 8, Train Loss: 18.92, Train Accuracy: 30.83
# Epoch 2, Episode 9, Train Loss: 18.53, Train Accuracy: 31.56
# Epoch 2, Episode 10, Train Loss: 19.11, Train Accuracy: 32.67
# Epoch 2, Episode 11, Train Loss: 18.77, Train Accuracy: 32.61
# Epoch 2, Episode 12, Train Loss: 18.62, Train Accuracy: 32.56
# Epoch 2, Episode 13, Train Loss: 18.36, Train Accuracy: 31.90
# Epoch 2, Episode 14, Train Loss: 18.37, Train Accuracy: 32.67
# Epoch 2, Episode 15, Train Loss: 18.13, Train Accuracy: 32.53
# Epoch 2, Episode 16, Train Loss: 18.00, Train Accuracy: 32.33
# Epoch 2, Episode 17, Train Loss: 17.89, Train Accuracy: 32.55
# Epoch 2, Episode 18, Train Loss: 18.11, Train Accuracy: 32.74
# Epoch 2, Episode 19, Train Loss: 17.97, Train Accuracy: 32.07
# Epoch 2, Episode 20, Train Loss: 18.21, Train Accuracy: 32.53
# Epoch 2, Episode 21, Train Loss: 18.33, Train Accuracy: 32.57
# Epoch 2, Episode 22, Train Loss: 18.39, Train Accuracy: 32.97
# Epoch 2, Episode 23, Train Loss: 18.41, Train Accuracy: 33.28
# Epoch 2, Episode 24, Train Loss: 18.54, Train Accuracy: 33.67
# Epoch 2, Episode 25, Train Loss: 18.46, Train Accuracy: 33.49
# Epoch 2, Episode 26, Train Loss: 18.47, Train Accuracy: 34.00
# Epoch 2, Episode 27, Train Loss: 18.38, Train Accuracy: 33.38
# Epoch 2, Episode 28, Train Loss: 18.51, Train Accuracy: 33.62
# Epoch 2, Episode 29, Train Loss: 18.58, Train Accuracy: 33.98
# Epoch 2, Episode 30, Train Loss: 18.44, Train Accuracy: 33.78
# Epoch 2, Episode 31, Train Loss: 18.50, Train Accuracy: 34.11
# Epoch 2, Episode 32, Train Loss: 18.45, Train Accuracy: 33.67
# Epoch 2, Episode 33, Train Loss: 18.53, Train Accuracy: 33.90
# Epoch 2, Episode 34, Train Loss: 18.51, Train Accuracy: 33.84
# Epoch 2, Episode 35, Train Loss: 18.43, Train Accuracy: 33.87
# Epoch 2, Episode 36, Train Loss: 18.50, Train Accuracy: 33.96
# Epoch 2, Episode 37, Train Loss: 18.50, Train Accuracy: 33.98
# Epoch 2, Episode 38, Train Loss: 18.48, Train Accuracy: 34.07
# Epoch 2, Episode 39, Train Loss: 18.44, Train Accuracy: 34.02
# Epoch 2, Episode 40, Train Loss: 18.42, Train Accuracy: 34.03
# Epoch 2, Episode 41, Train Loss: 18.38, Train Accuracy: 33.89
# Epoch 2, Episode 42, Train Loss: 18.50, Train Accuracy: 34.22
# Epoch 2, Episode 43, Train Loss: 18.56, Train Accuracy: 34.20
# Epoch 2, Episode 44, Train Loss: 18.64, Train Accuracy: 34.61
# Epoch 2, Episode 45, Train Loss: 18.71, Train Accuracy: 34.55
# Epoch 2, Episode 46, Train Loss: 18.71, Train Accuracy: 34.43
# Epoch 2, Episode 47, Train Loss: 18.70, Train Accuracy: 34.18
# Epoch 2, Episode 48, Train Loss: 18.74, Train Accuracy: 34.25
# Epoch 2, Episode 49, Train Loss: 18.70, Train Accuracy: 34.29
# Epoch 2, Episode 50, Train Loss: 18.67, Train Accuracy: 34.11
# Epoch 2, Episode 51, Train Loss: 18.62, Train Accuracy: 33.75
# Epoch 2, Episode 52, Train Loss: 18.67, Train Accuracy: 34.08
# Epoch 2, Episode 53, Train Loss: 18.64, Train Accuracy: 34.26
# Epoch 2, Episode 54, Train Loss: 18.62, Train Accuracy: 34.10
# Epoch 2, Episode 55, Train Loss: 18.54, Train Accuracy: 33.89
# Epoch 2, Episode 56, Train Loss: 18.49, Train Accuracy: 33.74
# Epoch 2, Episode 57, Train Loss: 18.46, Train Accuracy: 33.61
# Epoch 2, Episode 58, Train Loss: 18.51, Train Accuracy: 33.86
# Epoch 2, Episode 59, Train Loss: 18.45, Train Accuracy: 33.81
# Epoch 2, Episode 60, Train Loss: 18.52, Train Accuracy: 34.00
# Epoch 2, Episode 61, Train Loss: 18.48, Train Accuracy: 33.92
# Epoch 2, Episode 62, Train Loss: 18.52, Train Accuracy: 34.04
# Epoch 2, Episode 63, Train Loss: 18.56, Train Accuracy: 34.37
# Epoch 2, Episode 64, Train Loss: 18.58, Train Accuracy: 34.56
# Epoch 2, Episode 65, Train Loss: 18.60, Train Accuracy: 34.75
# Epoch 2, Episode 66, Train Loss: 18.69, Train Accuracy: 34.91
# Epoch 2, Episode 67, Train Loss: 18.74, Train Accuracy: 35.08
# Epoch 2, Episode 68, Train Loss: 18.84, Train Accuracy: 35.18
# Epoch 2, Episode 69, Train Loss: 18.90, Train Accuracy: 35.30
# Epoch 2, Episode 70, Train Loss: 18.88, Train Accuracy: 35.26
# Epoch 2, Episode 71, Train Loss: 18.85, Train Accuracy: 35.25
# Epoch 2, Episode 72, Train Loss: 18.94, Train Accuracy: 35.09
# Epoch 2, Episode 73, Train Loss: 18.90, Train Accuracy: 35.07
# Epoch 2, Episode 74, Train Loss: 18.85, Train Accuracy: 34.85
# Epoch 2, Episode 75, Train Loss: 18.86, Train Accuracy: 34.84
# Epoch 2, Episode 76, Train Loss: 18.84, Train Accuracy: 34.72
# Epoch 2, Episode 77, Train Loss: 18.79, Train Accuracy: 34.53
# Epoch 2, Episode 78, Train Loss: 18.84, Train Accuracy: 34.70
# Epoch 2, Episode 79, Train Loss: 18.82, Train Accuracy: 34.70
# Epoch 2, Episode 80, Train Loss: 18.79, Train Accuracy: 34.78
# Epoch 2, Episode 81, Train Loss: 18.79, Train Accuracy: 34.93
# Epoch 2, Episode 82, Train Loss: 18.81, Train Accuracy: 34.99
# Epoch 2, Episode 83, Train Loss: 18.76, Train Accuracy: 34.80
# Epoch 2, Episode 84, Train Loss: 18.77, Train Accuracy: 34.90
# Epoch 2, Episode 85, Train Loss: 18.81, Train Accuracy: 35.03
# Epoch 2, Episode 86, Train Loss: 18.74, Train Accuracy: 35.04
# Epoch 2, Episode 87, Train Loss: 18.71, Train Accuracy: 34.96
# Epoch 2, Episode 88, Train Loss: 18.67, Train Accuracy: 34.83
# Epoch 2, Episode 89, Train Loss: 18.71, Train Accuracy: 34.92
# Epoch 2, Episode 90, Train Loss: 18.66, Train Accuracy: 34.86
# Epoch 2, Episode 91, Train Loss: 18.62, Train Accuracy: 34.87
# Epoch 2, Episode 92, Train Loss: 18.61, Train Accuracy: 34.93
# Epoch 2, Episode 93, Train Loss: 18.63, Train Accuracy: 35.05
# Epoch 2, Episode 94, Train Loss: 18.62, Train Accuracy: 35.05
# Epoch 2, Episode 95, Train Loss: 18.62, Train Accuracy: 35.14
# Epoch 2, Episode 96, Train Loss: 18.66, Train Accuracy: 35.25
# Epoch 2, Episode 97, Train Loss: 18.66, Train Accuracy: 35.42
# Epoch 2, Episode 98, Train Loss: 18.70, Train Accuracy: 35.37
# Epoch 2, Episode 99, Train Loss: 18.71, Train Accuracy: 35.41
# Epoch 2, Episode 100, Train Loss: 18.68, Train Accuracy: 35.39
# Epoch 3, Episode 1, Train Loss: 17.20, Train Accuracy: 25.33
# Epoch 3, Episode 2, Train Loss: 16.67, Train Accuracy: 32.67
# Epoch 3, Episode 3, Train Loss: 17.92, Train Accuracy: 36.89
# Epoch 3, Episode 4, Train Loss: 17.72, Train Accuracy: 38.33
# Epoch 3, Episode 5, Train Loss: 18.55, Train Accuracy: 40.53
# Epoch 3, Episode 6, Train Loss: 19.97, Train Accuracy: 40.00
# Epoch 3, Episode 7, Train Loss: 20.29, Train Accuracy: 40.76
# Epoch 3, Episode 8, Train Loss: 19.68, Train Accuracy: 38.17
# Epoch 3, Episode 9, Train Loss: 19.32, Train Accuracy: 37.48
# Epoch 3, Episode 10, Train Loss: 18.94, Train Accuracy: 36.80
# Epoch 3, Episode 11, Train Loss: 18.83, Train Accuracy: 36.36
# Epoch 3, Episode 12, Train Loss: 18.99, Train Accuracy: 37.56
# Epoch 3, Episode 13, Train Loss: 18.85, Train Accuracy: 37.23
# Epoch 3, Episode 14, Train Loss: 18.55, Train Accuracy: 36.38
# Epoch 3, Episode 15, Train Loss: 18.39, Train Accuracy: 35.47
# Epoch 3, Episode 16, Train Loss: 18.39, Train Accuracy: 35.42
# Epoch 3, Episode 17, Train Loss: 18.39, Train Accuracy: 35.14
# Epoch 3, Episode 18, Train Loss: 18.16, Train Accuracy: 34.81
# Epoch 3, Episode 19, Train Loss: 18.52, Train Accuracy: 34.81
# Epoch 3, Episode 20, Train Loss: 18.82, Train Accuracy: 35.40
# Epoch 3, Episode 21, Train Loss: 18.62, Train Accuracy: 34.92
# Epoch 3, Episode 22, Train Loss: 18.90, Train Accuracy: 35.39
# Epoch 3, Episode 23, Train Loss: 18.81, Train Accuracy: 35.19
# Epoch 3, Episode 24, Train Loss: 18.90, Train Accuracy: 35.22
# Epoch 3, Episode 25, Train Loss: 19.02, Train Accuracy: 35.57
# Epoch 3, Episode 26, Train Loss: 19.20, Train Accuracy: 36.10
# Epoch 3, Episode 27, Train Loss: 19.38, Train Accuracy: 36.05
# Epoch 3, Episode 28, Train Loss: 19.35, Train Accuracy: 36.10
# Epoch 3, Episode 29, Train Loss: 19.26, Train Accuracy: 35.86
# Epoch 3, Episode 30, Train Loss: 19.41, Train Accuracy: 36.04
# Epoch 3, Episode 31, Train Loss: 19.62, Train Accuracy: 36.17
# Epoch 3, Episode 32, Train Loss: 19.62, Train Accuracy: 36.21
# Epoch 3, Episode 33, Train Loss: 19.52, Train Accuracy: 35.84
# Epoch 3, Episode 34, Train Loss: 19.68, Train Accuracy: 35.92
# Epoch 3, Episode 35, Train Loss: 19.73, Train Accuracy: 36.00
# Epoch 3, Episode 36, Train Loss: 19.87, Train Accuracy: 35.93
# Epoch 3, Episode 37, Train Loss: 19.84, Train Accuracy: 36.07
# Epoch 3, Episode 38, Train Loss: 19.79, Train Accuracy: 36.39
# Epoch 3, Episode 39, Train Loss: 19.83, Train Accuracy: 36.21
# Epoch 3, Episode 40, Train Loss: 19.97, Train Accuracy: 36.37
# Epoch 3, Episode 41, Train Loss: 20.05, Train Accuracy: 36.75
# Epoch 3, Episode 42, Train Loss: 20.14, Train Accuracy: 36.60
# Epoch 3, Episode 43, Train Loss: 20.11, Train Accuracy: 36.56
# Epoch 3, Episode 44, Train Loss: 20.22, Train Accuracy: 36.82
# Epoch 3, Episode 45, Train Loss: 20.07, Train Accuracy: 36.62
# Epoch 3, Episode 46, Train Loss: 19.97, Train Accuracy: 36.35
# Epoch 3, Episode 47, Train Loss: 19.94, Train Accuracy: 36.34
# Epoch 3, Episode 48, Train Loss: 20.02, Train Accuracy: 36.31
# Epoch 3, Episode 49, Train Loss: 19.94, Train Accuracy: 36.52
# Epoch 3, Episode 50, Train Loss: 20.06, Train Accuracy: 36.75
# Epoch 3, Episode 51, Train Loss: 20.10, Train Accuracy: 36.86
# Epoch 3, Episode 52, Train Loss: 20.06, Train Accuracy: 36.92
# Epoch 3, Episode 53, Train Loss: 20.11, Train Accuracy: 36.88
# Epoch 3, Episode 54, Train Loss: 20.04, Train Accuracy: 36.86
# Epoch 3, Episode 55, Train Loss: 20.12, Train Accuracy: 36.99
# Epoch 3, Episode 56, Train Loss: 20.01, Train Accuracy: 36.81
# Epoch 3, Episode 57, Train Loss: 20.04, Train Accuracy: 36.73
# Epoch 3, Episode 58, Train Loss: 20.03, Train Accuracy: 36.76
# Epoch 3, Episode 59, Train Loss: 20.05, Train Accuracy: 37.15
# Epoch 3, Episode 60, Train Loss: 19.98, Train Accuracy: 36.91
# Epoch 3, Episode 61, Train Loss: 20.06, Train Accuracy: 36.87
# Epoch 3, Episode 62, Train Loss: 20.16, Train Accuracy: 36.95
# Epoch 3, Episode 63, Train Loss: 20.19, Train Accuracy: 36.89
# Epoch 3, Episode 64, Train Loss: 20.10, Train Accuracy: 36.83
# Epoch 3, Episode 65, Train Loss: 20.15, Train Accuracy: 36.94
# Epoch 3, Episode 66, Train Loss: 20.06, Train Accuracy: 36.85
# Epoch 3, Episode 67, Train Loss: 20.11, Train Accuracy: 36.82
# Epoch 3, Episode 68, Train Loss: 20.17, Train Accuracy: 36.82
# Epoch 3, Episode 69, Train Loss: 20.09, Train Accuracy: 36.66
# Epoch 3, Episode 70, Train Loss: 20.09, Train Accuracy: 36.72
# Epoch 3, Episode 71, Train Loss: 20.02, Train Accuracy: 36.75
# Epoch 3, Episode 72, Train Loss: 19.98, Train Accuracy: 36.56
# Epoch 3, Episode 73, Train Loss: 19.94, Train Accuracy: 36.31
# Epoch 3, Episode 74, Train Loss: 19.86, Train Accuracy: 36.16
# Epoch 3, Episode 75, Train Loss: 19.85, Train Accuracy: 36.27
# Epoch 3, Episode 76, Train Loss: 19.81, Train Accuracy: 36.19
# Epoch 3, Episode 77, Train Loss: 19.83, Train Accuracy: 36.26
# Epoch 3, Episode 78, Train Loss: 19.85, Train Accuracy: 36.34
# Epoch 3, Episode 79, Train Loss: 19.76, Train Accuracy: 36.15
# Epoch 3, Episode 80, Train Loss: 19.73, Train Accuracy: 36.05
# Epoch 3, Episode 81, Train Loss: 19.74, Train Accuracy: 36.10
# Epoch 3, Episode 82, Train Loss: 19.74, Train Accuracy: 36.07
# Epoch 3, Episode 83, Train Loss: 19.66, Train Accuracy: 35.95
# Epoch 3, Episode 84, Train Loss: 19.63, Train Accuracy: 35.89
# Epoch 3, Episode 85, Train Loss: 19.64, Train Accuracy: 35.94
# Epoch 3, Episode 86, Train Loss: 19.57, Train Accuracy: 35.83
# Epoch 3, Episode 87, Train Loss: 19.56, Train Accuracy: 35.94
# Epoch 3, Episode 88, Train Loss: 19.49, Train Accuracy: 35.74
# Epoch 3, Episode 89, Train Loss: 19.51, Train Accuracy: 35.82
# Epoch 3, Episode 90, Train Loss: 19.45, Train Accuracy: 35.81
# Epoch 3, Episode 91, Train Loss: 19.47, Train Accuracy: 35.87
# Epoch 3, Episode 92, Train Loss: 19.42, Train Accuracy: 35.77
# Epoch 3, Episode 93, Train Loss: 19.34, Train Accuracy: 35.64
# Epoch 3, Episode 94, Train Loss: 19.40, Train Accuracy: 35.70
# Epoch 3, Episode 95, Train Loss: 19.34, Train Accuracy: 35.55
# Epoch 3, Episode 96, Train Loss: 19.32, Train Accuracy: 35.56
# Epoch 3, Episode 97, Train Loss: 19.27, Train Accuracy: 35.49
# Epoch 3, Episode 98, Train Loss: 19.26, Train Accuracy: 35.41
# Epoch 3, Episode 99, Train Loss: 19.20, Train Accuracy: 35.31
# Epoch 3, Episode 100, Train Loss: 19.18, Train Accuracy: 35.36
# Epoch 4, Episode 1, Train Loss: 22.79, Train Accuracy: 42.67
# Epoch 4, Episode 2, Train Loss: 19.67, Train Accuracy: 40.00
# Epoch 4, Episode 3, Train Loss: 17.96, Train Accuracy: 36.44
# Epoch 4, Episode 4, Train Loss: 19.34, Train Accuracy: 39.67
# Epoch 4, Episode 5, Train Loss: 19.37, Train Accuracy: 39.73
# Epoch 4, Episode 6, Train Loss: 20.09, Train Accuracy: 40.89
# Epoch 4, Episode 7, Train Loss: 19.23, Train Accuracy: 39.43
# Epoch 4, Episode 8, Train Loss: 19.15, Train Accuracy: 39.17
# Epoch 4, Episode 9, Train Loss: 19.24, Train Accuracy: 39.41
# Epoch 4, Episode 10, Train Loss: 19.67, Train Accuracy: 39.73
# Epoch 4, Episode 11, Train Loss: 19.88, Train Accuracy: 40.24
# Epoch 4, Episode 12, Train Loss: 19.96, Train Accuracy: 40.22
# Epoch 4, Episode 13, Train Loss: 19.72, Train Accuracy: 39.38
# Epoch 4, Episode 14, Train Loss: 19.74, Train Accuracy: 39.81
# Epoch 4, Episode 15, Train Loss: 19.46, Train Accuracy: 38.84
# Epoch 4, Episode 16, Train Loss: 19.47, Train Accuracy: 39.00
# Epoch 4, Episode 17, Train Loss: 19.15, Train Accuracy: 38.59
# Epoch 4, Episode 18, Train Loss: 19.33, Train Accuracy: 38.74
# Epoch 4, Episode 19, Train Loss: 19.15, Train Accuracy: 38.88
# Epoch 4, Episode 20, Train Loss: 19.61, Train Accuracy: 39.07
# Epoch 4, Episode 21, Train Loss: 19.36, Train Accuracy: 38.41
# Epoch 4, Episode 22, Train Loss: 19.09, Train Accuracy: 38.36
# Epoch 4, Episode 23, Train Loss: 18.91, Train Accuracy: 38.14
# Epoch 4, Episode 24, Train Loss: 18.96, Train Accuracy: 38.78
# Epoch 4, Episode 25, Train Loss: 18.75, Train Accuracy: 38.19
# Epoch 4, Episode 26, Train Loss: 18.87, Train Accuracy: 38.51
# Epoch 4, Episode 27, Train Loss: 19.10, Train Accuracy: 38.57
# Epoch 4, Episode 28, Train Loss: 19.10, Train Accuracy: 38.76
# Epoch 4, Episode 29, Train Loss: 18.94, Train Accuracy: 38.25
# Epoch 4, Episode 30, Train Loss: 18.71, Train Accuracy: 37.56
# Epoch 4, Episode 31, Train Loss: 18.78, Train Accuracy: 37.68
# Epoch 4, Episode 32, Train Loss: 18.88, Train Accuracy: 37.79
# Epoch 4, Episode 33, Train Loss: 19.03, Train Accuracy: 37.98
# Epoch 4, Episode 34, Train Loss: 18.85, Train Accuracy: 37.88
# Epoch 4, Episode 35, Train Loss: 19.00, Train Accuracy: 38.02
# Epoch 4, Episode 36, Train Loss: 19.07, Train Accuracy: 37.96
# Epoch 4, Episode 37, Train Loss: 19.21, Train Accuracy: 38.38
# Epoch 4, Episode 38, Train Loss: 19.13, Train Accuracy: 38.46
# Epoch 4, Episode 39, Train Loss: 19.27, Train Accuracy: 38.70
# Epoch 4, Episode 40, Train Loss: 19.37, Train Accuracy: 39.03
# Epoch 4, Episode 41, Train Loss: 19.22, Train Accuracy: 38.89
# Epoch 4, Episode 42, Train Loss: 19.11, Train Accuracy: 38.70
# Epoch 4, Episode 43, Train Loss: 19.02, Train Accuracy: 38.70
# Epoch 4, Episode 44, Train Loss: 19.14, Train Accuracy: 38.97
# Epoch 4, Episode 45, Train Loss: 19.23, Train Accuracy: 39.08
# Epoch 4, Episode 46, Train Loss: 19.34, Train Accuracy: 39.16
# Epoch 4, Episode 47, Train Loss: 19.23, Train Accuracy: 39.12
# Epoch 4, Episode 48, Train Loss: 19.13, Train Accuracy: 39.03
# Epoch 4, Episode 49, Train Loss: 19.24, Train Accuracy: 39.16
# Epoch 4, Episode 50, Train Loss: 19.23, Train Accuracy: 39.04
# Epoch 4, Episode 51, Train Loss: 19.20, Train Accuracy: 39.06
# Epoch 4, Episode 52, Train Loss: 19.12, Train Accuracy: 38.79
# Epoch 4, Episode 53, Train Loss: 19.10, Train Accuracy: 38.72
# Epoch 4, Episode 54, Train Loss: 19.19, Train Accuracy: 38.72
# Epoch 4, Episode 55, Train Loss: 19.09, Train Accuracy: 38.50
# Epoch 4, Episode 56, Train Loss: 19.17, Train Accuracy: 38.60
# Epoch 4, Episode 57, Train Loss: 19.28, Train Accuracy: 38.57
# Epoch 4, Episode 58, Train Loss: 19.23, Train Accuracy: 38.48
# Epoch 4, Episode 59, Train Loss: 19.34, Train Accuracy: 38.58
# Epoch 4, Episode 60, Train Loss: 19.38, Train Accuracy: 38.69
# Epoch 4, Episode 61, Train Loss: 19.36, Train Accuracy: 38.56
# Epoch 4, Episode 62, Train Loss: 19.41, Train Accuracy: 38.54
# Epoch 4, Episode 63, Train Loss: 19.41, Train Accuracy: 38.54
# Epoch 4, Episode 64, Train Loss: 19.52, Train Accuracy: 38.69
# Epoch 4, Episode 65, Train Loss: 19.56, Train Accuracy: 38.61
# Epoch 4, Episode 66, Train Loss: 19.63, Train Accuracy: 38.71
# Epoch 4, Episode 67, Train Loss: 19.73, Train Accuracy: 38.81
# Epoch 4, Episode 68, Train Loss: 19.77, Train Accuracy: 38.90
# Epoch 4, Episode 69, Train Loss: 19.85, Train Accuracy: 39.09
# Epoch 4, Episode 70, Train Loss: 19.80, Train Accuracy: 39.07
# Epoch 4, Episode 71, Train Loss: 19.83, Train Accuracy: 39.15
# Epoch 4, Episode 72, Train Loss: 19.97, Train Accuracy: 39.37
# Epoch 4, Episode 73, Train Loss: 20.03, Train Accuracy: 39.38
# Epoch 4, Episode 74, Train Loss: 19.95, Train Accuracy: 39.23
# Epoch 4, Episode 75, Train Loss: 19.88, Train Accuracy: 38.95
# Epoch 4, Episode 76, Train Loss: 19.80, Train Accuracy: 38.70
# Epoch 4, Episode 77, Train Loss: 19.86, Train Accuracy: 38.58
# Epoch 4, Episode 78, Train Loss: 19.90, Train Accuracy: 38.55
# Epoch 4, Episode 79, Train Loss: 19.86, Train Accuracy: 38.65
# Epoch 4, Episode 80, Train Loss: 19.91, Train Accuracy: 38.70
# Epoch 4, Episode 81, Train Loss: 19.93, Train Accuracy: 38.72
# Epoch 4, Episode 82, Train Loss: 19.85, Train Accuracy: 38.59
# Epoch 4, Episode 83, Train Loss: 19.89, Train Accuracy: 38.67
# Epoch 4, Episode 84, Train Loss: 19.80, Train Accuracy: 38.52
# Epoch 4, Episode 85, Train Loss: 19.79, Train Accuracy: 38.62
# Epoch 4, Episode 86, Train Loss: 19.82, Train Accuracy: 38.73
# Epoch 4, Episode 87, Train Loss: 19.74, Train Accuracy: 38.59
# Epoch 4, Episode 88, Train Loss: 19.75, Train Accuracy: 38.67
# Epoch 4, Episode 89, Train Loss: 19.78, Train Accuracy: 38.86
# Epoch 4, Episode 90, Train Loss: 19.71, Train Accuracy: 38.67
# Epoch 4, Episode 91, Train Loss: 19.70, Train Accuracy: 38.71
# Epoch 4, Episode 92, Train Loss: 19.72, Train Accuracy: 38.74
# Epoch 4, Episode 93, Train Loss: 19.75, Train Accuracy: 38.80
# Epoch 4, Episode 94, Train Loss: 19.75, Train Accuracy: 38.85
# Epoch 4, Episode 95, Train Loss: 19.77, Train Accuracy: 38.81
# Epoch 4, Episode 96, Train Loss: 19.75, Train Accuracy: 38.76
# Epoch 4, Episode 97, Train Loss: 19.77, Train Accuracy: 38.83
# Epoch 4, Episode 98, Train Loss: 19.78, Train Accuracy: 38.83
# Epoch 4, Episode 99, Train Loss: 19.81, Train Accuracy: 38.86
# Epoch 4, Episode 100, Train Loss: 19.79, Train Accuracy: 38.85
# Epoch 5, Episode 1, Train Loss: 16.18, Train Accuracy: 30.67
# Epoch 5, Episode 2, Train Loss: 18.20, Train Accuracy: 35.33
# Epoch 5, Episode 3, Train Loss: 16.43, Train Accuracy: 35.11
# Epoch 5, Episode 4, Train Loss: 18.80, Train Accuracy: 34.33
# Epoch 5, Episode 5, Train Loss: 19.22, Train Accuracy: 35.20
# Epoch 5, Episode 6, Train Loss: 19.37, Train Accuracy: 36.22
# Epoch 5, Episode 7, Train Loss: 19.83, Train Accuracy: 38.29
# Epoch 5, Episode 8, Train Loss: 19.20, Train Accuracy: 38.50
# Epoch 5, Episode 9, Train Loss: 18.88, Train Accuracy: 38.22
# Epoch 5, Episode 10, Train Loss: 18.39, Train Accuracy: 38.27
# Epoch 5, Episode 11, Train Loss: 18.58, Train Accuracy: 38.18
# Epoch 5, Episode 12, Train Loss: 18.76, Train Accuracy: 38.22
# Epoch 5, Episode 13, Train Loss: 18.38, Train Accuracy: 37.54
# Epoch 5, Episode 14, Train Loss: 18.28, Train Accuracy: 37.62
# Epoch 5, Episode 15, Train Loss: 18.13, Train Accuracy: 37.87
# Epoch 5, Episode 16, Train Loss: 18.52, Train Accuracy: 38.58
# Epoch 5, Episode 17, Train Loss: 18.41, Train Accuracy: 38.51
# Epoch 5, Episode 18, Train Loss: 18.38, Train Accuracy: 38.22
# Epoch 5, Episode 19, Train Loss: 18.27, Train Accuracy: 37.82
# Epoch 5, Episode 20, Train Loss: 18.54, Train Accuracy: 38.00
# Epoch 5, Episode 21, Train Loss: 18.54, Train Accuracy: 37.65
# Epoch 5, Episode 22, Train Loss: 18.86, Train Accuracy: 38.18
# Epoch 5, Episode 23, Train Loss: 18.63, Train Accuracy: 37.86
# Epoch 5, Episode 24, Train Loss: 18.87, Train Accuracy: 38.33
# Epoch 5, Episode 25, Train Loss: 19.16, Train Accuracy: 38.29
# Epoch 5, Episode 26, Train Loss: 19.31, Train Accuracy: 38.51
# Epoch 5, Episode 27, Train Loss: 19.34, Train Accuracy: 38.32
# Epoch 5, Episode 28, Train Loss: 19.60, Train Accuracy: 38.48
# Epoch 5, Episode 29, Train Loss: 19.79, Train Accuracy: 38.90
# Epoch 5, Episode 30, Train Loss: 19.99, Train Accuracy: 39.42
# Epoch 5, Episode 31, Train Loss: 20.05, Train Accuracy: 39.83
# Epoch 5, Episode 32, Train Loss: 19.98, Train Accuracy: 39.67
# Epoch 5, Episode 33, Train Loss: 20.08, Train Accuracy: 39.39
# Epoch 5, Episode 34, Train Loss: 19.90, Train Accuracy: 38.98
# Epoch 5, Episode 35, Train Loss: 20.03, Train Accuracy: 39.09
# Epoch 5, Episode 36, Train Loss: 20.00, Train Accuracy: 39.26
# Epoch 5, Episode 37, Train Loss: 20.07, Train Accuracy: 39.42
# Epoch 5, Episode 38, Train Loss: 20.21, Train Accuracy: 39.54
# Epoch 5, Episode 39, Train Loss: 20.28, Train Accuracy: 39.69
# Epoch 5, Episode 40, Train Loss: 20.15, Train Accuracy: 39.33
# Epoch 5, Episode 41, Train Loss: 20.05, Train Accuracy: 39.58
# Epoch 5, Episode 42, Train Loss: 20.04, Train Accuracy: 39.75
# Epoch 5, Episode 43, Train Loss: 19.92, Train Accuracy: 39.35
# Epoch 5, Episode 44, Train Loss: 20.04, Train Accuracy: 39.42
# Epoch 5, Episode 45, Train Loss: 20.19, Train Accuracy: 39.70
# Epoch 5, Episode 46, Train Loss: 20.33, Train Accuracy: 39.71
# Epoch 5, Episode 47, Train Loss: 20.29, Train Accuracy: 39.52
# Epoch 5, Episode 48, Train Loss: 20.20, Train Accuracy: 39.61
# Epoch 5, Episode 49, Train Loss: 20.22, Train Accuracy: 39.76
# Epoch 5, Episode 50, Train Loss: 20.27, Train Accuracy: 39.84
# Epoch 5, Episode 51, Train Loss: 20.15, Train Accuracy: 39.56
# Epoch 5, Episode 52, Train Loss: 20.11, Train Accuracy: 39.77
# Epoch 5, Episode 53, Train Loss: 20.02, Train Accuracy: 39.82
# Epoch 5, Episode 54, Train Loss: 20.07, Train Accuracy: 39.75
# Epoch 5, Episode 55, Train Loss: 20.03, Train Accuracy: 39.52
# Epoch 5, Episode 56, Train Loss: 20.15, Train Accuracy: 39.55
# Epoch 5, Episode 57, Train Loss: 20.20, Train Accuracy: 39.81
# Epoch 5, Episode 58, Train Loss: 20.15, Train Accuracy: 39.61
# Epoch 5, Episode 59, Train Loss: 20.05, Train Accuracy: 39.32
# Epoch 5, Episode 60, Train Loss: 20.14, Train Accuracy: 39.38
# Epoch 5, Episode 61, Train Loss: 20.19, Train Accuracy: 39.34
# Epoch 5, Episode 62, Train Loss: 20.10, Train Accuracy: 39.18
# Epoch 5, Episode 63, Train Loss: 20.13, Train Accuracy: 39.24
# Epoch 5, Episode 64, Train Loss: 20.11, Train Accuracy: 39.12
# Epoch 5, Episode 65, Train Loss: 20.18, Train Accuracy: 39.28
# Epoch 5, Episode 66, Train Loss: 20.11, Train Accuracy: 39.19
# Epoch 5, Episode 67, Train Loss: 20.15, Train Accuracy: 39.14
# Epoch 5, Episode 68, Train Loss: 20.22, Train Accuracy: 39.39
# Epoch 5, Episode 69, Train Loss: 20.13, Train Accuracy: 39.34
# Epoch 5, Episode 70, Train Loss: 20.04, Train Accuracy: 39.16
# Epoch 5, Episode 71, Train Loss: 19.99, Train Accuracy: 39.23
# Epoch 5, Episode 72, Train Loss: 20.05, Train Accuracy: 39.30
# Epoch 5, Episode 73, Train Loss: 20.15, Train Accuracy: 39.51
# Epoch 5, Episode 74, Train Loss: 20.11, Train Accuracy: 39.44
# Epoch 5, Episode 75, Train Loss: 20.12, Train Accuracy: 39.52
# Epoch 5, Episode 76, Train Loss: 20.14, Train Accuracy: 39.49
# Epoch 5, Episode 77, Train Loss: 20.15, Train Accuracy: 39.53
# Epoch 5, Episode 78, Train Loss: 20.18, Train Accuracy: 39.61
# Epoch 5, Episode 79, Train Loss: 20.17, Train Accuracy: 39.48
# Epoch 5, Episode 80, Train Loss: 20.13, Train Accuracy: 39.48
# Epoch 5, Episode 81, Train Loss: 20.07, Train Accuracy: 39.28
# Epoch 5, Episode 82, Train Loss: 20.03, Train Accuracy: 39.17
# Epoch 5, Episode 83, Train Loss: 19.97, Train Accuracy: 39.10
# Epoch 5, Episode 84, Train Loss: 20.03, Train Accuracy: 39.10
# Epoch 5, Episode 85, Train Loss: 20.09, Train Accuracy: 39.04
# Epoch 5, Episode 86, Train Loss: 20.06, Train Accuracy: 38.99
# Epoch 5, Episode 87, Train Loss: 20.02, Train Accuracy: 39.03
# Epoch 5, Episode 88, Train Loss: 20.00, Train Accuracy: 39.02
# Epoch 5, Episode 89, Train Loss: 20.02, Train Accuracy: 39.10
# Epoch 5, Episode 90, Train Loss: 20.06, Train Accuracy: 39.16
# Epoch 5, Episode 91, Train Loss: 19.98, Train Accuracy: 38.93
# Epoch 5, Episode 92, Train Loss: 19.97, Train Accuracy: 38.86
# Epoch 5, Episode 93, Train Loss: 19.94, Train Accuracy: 38.85
# Epoch 5, Episode 94, Train Loss: 19.98, Train Accuracy: 38.89
# Epoch 5, Episode 95, Train Loss: 20.04, Train Accuracy: 38.85
# Epoch 5, Episode 96, Train Loss: 20.01, Train Accuracy: 38.83
# Epoch 5, Episode 97, Train Loss: 19.92, Train Accuracy: 38.79
# Epoch 5, Episode 98, Train Loss: 19.92, Train Accuracy: 38.94
# Epoch 5, Episode 99, Train Loss: 19.96, Train Accuracy: 39.08
# Epoch 5, Episode 100, Train Loss: 19.99, Train Accuracy: 39.21
# Epoch 6, Episode 1, Train Loss: 28.57, Train Accuracy: 44.00
# Epoch 6, Episode 2, Train Loss: 20.76, Train Accuracy: 36.00
# Epoch 6, Episode 3, Train Loss: 24.11, Train Accuracy: 35.11
# Epoch 6, Episode 4, Train Loss: 21.54, Train Accuracy: 34.33
# Epoch 6, Episode 5, Train Loss: 21.68, Train Accuracy: 35.47
# Epoch 6, Episode 6, Train Loss: 21.69, Train Accuracy: 37.11
# Epoch 6, Episode 7, Train Loss: 21.19, Train Accuracy: 37.90
# Epoch 6, Episode 8, Train Loss: 20.65, Train Accuracy: 38.17
# Epoch 6, Episode 9, Train Loss: 20.30, Train Accuracy: 37.48
# Epoch 6, Episode 10, Train Loss: 20.55, Train Accuracy: 37.47
# Epoch 6, Episode 11, Train Loss: 20.26, Train Accuracy: 36.97
# Epoch 6, Episode 12, Train Loss: 19.59, Train Accuracy: 35.89
# Epoch 6, Episode 13, Train Loss: 19.06, Train Accuracy: 34.87
# Epoch 6, Episode 14, Train Loss: 19.09, Train Accuracy: 35.24
# Epoch 6, Episode 15, Train Loss: 19.41, Train Accuracy: 35.73
# Epoch 6, Episode 16, Train Loss: 18.90, Train Accuracy: 35.33
# Epoch 6, Episode 17, Train Loss: 19.17, Train Accuracy: 35.84
# Epoch 6, Episode 18, Train Loss: 18.85, Train Accuracy: 35.48
# Epoch 6, Episode 19, Train Loss: 19.07, Train Accuracy: 36.49
# Epoch 6, Episode 20, Train Loss: 19.30, Train Accuracy: 36.67
# Epoch 6, Episode 21, Train Loss: 19.12, Train Accuracy: 36.57
# Epoch 6, Episode 22, Train Loss: 19.44, Train Accuracy: 37.27
# Epoch 6, Episode 23, Train Loss: 19.48, Train Accuracy: 37.80
# Epoch 6, Episode 24, Train Loss: 19.64, Train Accuracy: 38.06
# Epoch 6, Episode 25, Train Loss: 19.92, Train Accuracy: 37.97
# Epoch 6, Episode 26, Train Loss: 19.86, Train Accuracy: 37.69
# Epoch 6, Episode 27, Train Loss: 19.83, Train Accuracy: 37.58
# Epoch 6, Episode 28, Train Loss: 20.03, Train Accuracy: 37.86
# Epoch 6, Episode 29, Train Loss: 20.11, Train Accuracy: 38.07
# Epoch 6, Episode 30, Train Loss: 20.00, Train Accuracy: 38.04
# Epoch 6, Episode 31, Train Loss: 20.06, Train Accuracy: 38.11
# Epoch 6, Episode 32, Train Loss: 20.19, Train Accuracy: 38.46
# Epoch 6, Episode 33, Train Loss: 20.09, Train Accuracy: 38.42
# Epoch 6, Episode 34, Train Loss: 20.04, Train Accuracy: 38.47
# Epoch 6, Episode 35, Train Loss: 20.00, Train Accuracy: 38.70
# Epoch 6, Episode 36, Train Loss: 19.87, Train Accuracy: 38.85
# Epoch 6, Episode 37, Train Loss: 19.71, Train Accuracy: 38.67
# Epoch 6, Episode 38, Train Loss: 19.79, Train Accuracy: 38.77
# Epoch 6, Episode 39, Train Loss: 19.90, Train Accuracy: 38.94
# Epoch 6, Episode 40, Train Loss: 19.75, Train Accuracy: 38.73
# Epoch 6, Episode 41, Train Loss: 19.71, Train Accuracy: 38.60
# Epoch 6, Episode 42, Train Loss: 19.55, Train Accuracy: 38.54
# Epoch 6, Episode 43, Train Loss: 19.40, Train Accuracy: 38.29
# Epoch 6, Episode 44, Train Loss: 19.38, Train Accuracy: 38.18
# Epoch 6, Episode 45, Train Loss: 19.23, Train Accuracy: 37.84
# Epoch 6, Episode 46, Train Loss: 19.10, Train Accuracy: 37.68
# Epoch 6, Episode 47, Train Loss: 19.22, Train Accuracy: 37.76
# Epoch 6, Episode 48, Train Loss: 19.30, Train Accuracy: 37.86
# Epoch 6, Episode 49, Train Loss: 19.39, Train Accuracy: 38.29
# Epoch 6, Episode 50, Train Loss: 19.55, Train Accuracy: 38.51
# Epoch 6, Episode 51, Train Loss: 19.44, Train Accuracy: 38.27
# Epoch 6, Episode 52, Train Loss: 19.31, Train Accuracy: 38.05
# Epoch 6, Episode 53, Train Loss: 19.29, Train Accuracy: 38.01
# Epoch 6, Episode 54, Train Loss: 19.42, Train Accuracy: 38.17
# Epoch 6, Episode 55, Train Loss: 19.45, Train Accuracy: 38.30
# Epoch 6, Episode 56, Train Loss: 19.59, Train Accuracy: 38.62
# Epoch 6, Episode 57, Train Loss: 19.58, Train Accuracy: 38.57
# Epoch 6, Episode 58, Train Loss: 19.45, Train Accuracy: 38.25
# Epoch 6, Episode 59, Train Loss: 19.55, Train Accuracy: 38.26
# Epoch 6, Episode 60, Train Loss: 19.68, Train Accuracy: 38.29
# Epoch 6, Episode 61, Train Loss: 19.78, Train Accuracy: 38.49
# Epoch 6, Episode 62, Train Loss: 19.74, Train Accuracy: 38.47
# Epoch 6, Episode 63, Train Loss: 19.62, Train Accuracy: 38.33
# Epoch 6, Episode 64, Train Loss: 19.63, Train Accuracy: 38.35
# Epoch 6, Episode 65, Train Loss: 19.55, Train Accuracy: 38.24
# Epoch 6, Episode 66, Train Loss: 19.48, Train Accuracy: 38.20
# Epoch 6, Episode 67, Train Loss: 19.37, Train Accuracy: 38.09
# Epoch 6, Episode 68, Train Loss: 19.41, Train Accuracy: 38.14
# Epoch 6, Episode 69, Train Loss: 19.31, Train Accuracy: 38.09
# Epoch 6, Episode 70, Train Loss: 19.30, Train Accuracy: 37.98
# Epoch 6, Episode 71, Train Loss: 19.19, Train Accuracy: 37.75
# Epoch 6, Episode 72, Train Loss: 19.14, Train Accuracy: 37.63
# Epoch 6, Episode 73, Train Loss: 19.24, Train Accuracy: 37.83
# Epoch 6, Episode 74, Train Loss: 19.14, Train Accuracy: 37.60
# Epoch 6, Episode 75, Train Loss: 19.16, Train Accuracy: 37.72
# Epoch 6, Episode 76, Train Loss: 19.14, Train Accuracy: 37.65
# Epoch 6, Episode 77, Train Loss: 19.17, Train Accuracy: 37.78
# Epoch 6, Episode 78, Train Loss: 19.08, Train Accuracy: 37.62
# Epoch 6, Episode 79, Train Loss: 19.07, Train Accuracy: 37.59
# Epoch 6, Episode 80, Train Loss: 19.01, Train Accuracy: 37.65
# Epoch 6, Episode 81, Train Loss: 19.12, Train Accuracy: 37.71
# Epoch 6, Episode 82, Train Loss: 19.21, Train Accuracy: 37.85
# Epoch 6, Episode 83, Train Loss: 19.27, Train Accuracy: 37.93
# Epoch 6, Episode 84, Train Loss: 19.18, Train Accuracy: 37.81
# Epoch 6, Episode 85, Train Loss: 19.08, Train Accuracy: 37.66
# Epoch 6, Episode 86, Train Loss: 18.99, Train Accuracy: 37.61
# Epoch 6, Episode 87, Train Loss: 18.96, Train Accuracy: 37.70
# Epoch 6, Episode 88, Train Loss: 19.00, Train Accuracy: 37.74
# Epoch 6, Episode 89, Train Loss: 19.03, Train Accuracy: 37.81
# Epoch 6, Episode 90, Train Loss: 18.98, Train Accuracy: 37.82
# Epoch 6, Episode 91, Train Loss: 18.94, Train Accuracy: 37.83
# Epoch 6, Episode 92, Train Loss: 18.90, Train Accuracy: 37.80
# Epoch 6, Episode 93, Train Loss: 18.98, Train Accuracy: 37.84
# Epoch 6, Episode 94, Train Loss: 18.98, Train Accuracy: 37.91
# Epoch 6, Episode 95, Train Loss: 19.01, Train Accuracy: 37.99
# Epoch 6, Episode 96, Train Loss: 19.05, Train Accuracy: 38.18
# Epoch 6, Episode 97, Train Loss: 19.07, Train Accuracy: 38.16
# Epoch 6, Episode 98, Train Loss: 19.13, Train Accuracy: 38.16
# Epoch 6, Episode 99, Train Loss: 19.13, Train Accuracy: 38.29
# Epoch 6, Episode 100, Train Loss: 19.12, Train Accuracy: 38.28
# Epoch 7, Episode 1, Train Loss: 23.38, Train Accuracy: 48.00
# Epoch 7, Episode 2, Train Loss: 24.43, Train Accuracy: 46.00
# Epoch 7, Episode 3, Train Loss: 22.80, Train Accuracy: 44.89
# Epoch 7, Episode 4, Train Loss: 20.67, Train Accuracy: 42.00
# Epoch 7, Episode 5, Train Loss: 20.64, Train Accuracy: 42.93
# Epoch 7, Episode 6, Train Loss: 21.70, Train Accuracy: 43.56
# Epoch 7, Episode 7, Train Loss: 21.50, Train Accuracy: 43.05
# Epoch 7, Episode 8, Train Loss: 21.04, Train Accuracy: 43.33
# Epoch 7, Episode 9, Train Loss: 20.36, Train Accuracy: 42.96
# Epoch 7, Episode 10, Train Loss: 20.32, Train Accuracy: 43.20
# Epoch 7, Episode 11, Train Loss: 20.23, Train Accuracy: 42.42
# Epoch 7, Episode 12, Train Loss: 19.73, Train Accuracy: 41.56
# Epoch 7, Episode 13, Train Loss: 19.90, Train Accuracy: 42.15
# Epoch 7, Episode 14, Train Loss: 20.20, Train Accuracy: 42.86
# Epoch 7, Episode 15, Train Loss: 20.22, Train Accuracy: 43.20
# Epoch 7, Episode 16, Train Loss: 19.69, Train Accuracy: 42.83
# Epoch 7, Episode 17, Train Loss: 19.30, Train Accuracy: 41.73
# Epoch 7, Episode 18, Train Loss: 19.07, Train Accuracy: 41.70
# Epoch 7, Episode 19, Train Loss: 18.96, Train Accuracy: 41.68
# Epoch 7, Episode 20, Train Loss: 18.61, Train Accuracy: 41.07
# Epoch 7, Episode 21, Train Loss: 18.31, Train Accuracy: 40.00
# Epoch 7, Episode 22, Train Loss: 18.49, Train Accuracy: 40.36
# Epoch 7, Episode 23, Train Loss: 18.39, Train Accuracy: 40.17
# Epoch 7, Episode 24, Train Loss: 18.14, Train Accuracy: 39.61
# Epoch 7, Episode 25, Train Loss: 18.02, Train Accuracy: 39.79
# Epoch 7, Episode 26, Train Loss: 18.26, Train Accuracy: 39.59
# Epoch 7, Episode 27, Train Loss: 18.13, Train Accuracy: 39.26
# Epoch 7, Episode 28, Train Loss: 17.99, Train Accuracy: 38.86
# Epoch 7, Episode 29, Train Loss: 17.94, Train Accuracy: 38.94
# Epoch 7, Episode 30, Train Loss: 18.03, Train Accuracy: 39.24
# Epoch 7, Episode 31, Train Loss: 18.11, Train Accuracy: 39.61
# Epoch 7, Episode 32, Train Loss: 18.39, Train Accuracy: 39.79
# Epoch 7, Episode 33, Train Loss: 18.30, Train Accuracy: 39.80
# Epoch 7, Episode 34, Train Loss: 18.25, Train Accuracy: 39.65
# Epoch 7, Episode 35, Train Loss: 18.35, Train Accuracy: 40.04
# Epoch 7, Episode 36, Train Loss: 18.20, Train Accuracy: 39.81
# Epoch 7, Episode 37, Train Loss: 18.38, Train Accuracy: 40.11
# Epoch 7, Episode 38, Train Loss: 18.24, Train Accuracy: 39.72
# Epoch 7, Episode 39, Train Loss: 18.43, Train Accuracy: 39.93
# Epoch 7, Episode 40, Train Loss: 18.44, Train Accuracy: 39.90
# Epoch 7, Episode 41, Train Loss: 18.34, Train Accuracy: 39.45
# Epoch 7, Episode 42, Train Loss: 18.47, Train Accuracy: 39.56
# Epoch 7, Episode 43, Train Loss: 18.41, Train Accuracy: 39.26
# Epoch 7, Episode 44, Train Loss: 18.32, Train Accuracy: 39.09
# Epoch 7, Episode 45, Train Loss: 18.30, Train Accuracy: 39.14
# Epoch 7, Episode 46, Train Loss: 18.35, Train Accuracy: 39.19
# Epoch 7, Episode 47, Train Loss: 18.55, Train Accuracy: 39.52
# Epoch 7, Episode 48, Train Loss: 18.66, Train Accuracy: 39.67
# Epoch 7, Episode 49, Train Loss: 18.68, Train Accuracy: 39.76
# Epoch 7, Episode 50, Train Loss: 18.78, Train Accuracy: 40.08
# Epoch 7, Episode 51, Train Loss: 18.78, Train Accuracy: 39.92
# Epoch 7, Episode 52, Train Loss: 18.94, Train Accuracy: 40.05
# Epoch 7, Episode 53, Train Loss: 19.05, Train Accuracy: 40.15
# Epoch 7, Episode 54, Train Loss: 18.96, Train Accuracy: 39.88
# Epoch 7, Episode 55, Train Loss: 18.89, Train Accuracy: 39.54
# Epoch 7, Episode 56, Train Loss: 18.77, Train Accuracy: 39.31
# Epoch 7, Episode 57, Train Loss: 18.82, Train Accuracy: 39.53
# Epoch 7, Episode 58, Train Loss: 18.88, Train Accuracy: 39.66
# Epoch 7, Episode 59, Train Loss: 18.75, Train Accuracy: 39.53
# Epoch 7, Episode 60, Train Loss: 18.76, Train Accuracy: 39.71
# Epoch 7, Episode 61, Train Loss: 18.71, Train Accuracy: 39.67
# Epoch 7, Episode 62, Train Loss: 18.61, Train Accuracy: 39.57
# Epoch 7, Episode 63, Train Loss: 18.61, Train Accuracy: 39.68
# Epoch 7, Episode 64, Train Loss: 18.60, Train Accuracy: 39.94
# Epoch 7, Episode 65, Train Loss: 18.51, Train Accuracy: 39.71
# Epoch 7, Episode 66, Train Loss: 18.50, Train Accuracy: 39.86
# Epoch 7, Episode 67, Train Loss: 18.54, Train Accuracy: 39.94
# Epoch 7, Episode 68, Train Loss: 18.45, Train Accuracy: 39.88
# Epoch 7, Episode 69, Train Loss: 18.58, Train Accuracy: 40.12
# Epoch 7, Episode 70, Train Loss: 18.69, Train Accuracy: 40.27
# Epoch 7, Episode 71, Train Loss: 18.69, Train Accuracy: 40.39
# Epoch 7, Episode 72, Train Loss: 18.79, Train Accuracy: 40.39
# Epoch 7, Episode 73, Train Loss: 18.71, Train Accuracy: 40.26
# Epoch 7, Episode 74, Train Loss: 18.79, Train Accuracy: 40.31
# Epoch 7, Episode 75, Train Loss: 18.76, Train Accuracy: 40.18
# Epoch 7, Episode 76, Train Loss: 18.70, Train Accuracy: 40.04
# Epoch 7, Episode 77, Train Loss: 18.68, Train Accuracy: 40.02
# Epoch 7, Episode 78, Train Loss: 18.76, Train Accuracy: 40.07
# Epoch 7, Episode 79, Train Loss: 18.68, Train Accuracy: 39.85
# Epoch 7, Episode 80, Train Loss: 18.66, Train Accuracy: 39.75
# Epoch 7, Episode 81, Train Loss: 18.67, Train Accuracy: 39.74
# Epoch 7, Episode 82, Train Loss: 18.72, Train Accuracy: 39.79
# Epoch 7, Episode 83, Train Loss: 18.73, Train Accuracy: 39.86
# Epoch 7, Episode 84, Train Loss: 18.75, Train Accuracy: 39.81
# Epoch 7, Episode 85, Train Loss: 18.77, Train Accuracy: 39.97
# Epoch 7, Episode 86, Train Loss: 18.77, Train Accuracy: 39.88
# Epoch 7, Episode 87, Train Loss: 18.82, Train Accuracy: 40.03
# Epoch 7, Episode 88, Train Loss: 18.85, Train Accuracy: 40.03
# Epoch 7, Episode 89, Train Loss: 18.89, Train Accuracy: 39.91
# Epoch 7, Episode 90, Train Loss: 18.94, Train Accuracy: 39.97
# Epoch 7, Episode 91, Train Loss: 18.87, Train Accuracy: 39.85
# Epoch 7, Episode 92, Train Loss: 18.80, Train Accuracy: 39.67
# Epoch 7, Episode 93, Train Loss: 18.76, Train Accuracy: 39.74
# Epoch 7, Episode 94, Train Loss: 18.85, Train Accuracy: 39.94
# Epoch 7, Episode 95, Train Loss: 18.83, Train Accuracy: 39.85
# Epoch 7, Episode 96, Train Loss: 18.76, Train Accuracy: 39.64
# Epoch 7, Episode 97, Train Loss: 18.71, Train Accuracy: 39.63
# Epoch 7, Episode 98, Train Loss: 18.78, Train Accuracy: 39.76
# Epoch 7, Episode 99, Train Loss: 18.77, Train Accuracy: 39.84
# Epoch 7, Episode 100, Train Loss: 18.83, Train Accuracy: 39.96
# Epoch 8, Episode 1, Train Loss: 12.30, Train Accuracy: 25.33
# Epoch 8, Episode 2, Train Loss: 14.25, Train Accuracy: 28.67
# Epoch 8, Episode 3, Train Loss: 16.48, Train Accuracy: 36.89
# Epoch 8, Episode 4, Train Loss: 17.13, Train Accuracy: 39.00
# Epoch 8, Episode 5, Train Loss: 16.87, Train Accuracy: 38.13
# Epoch 8, Episode 6, Train Loss: 16.17, Train Accuracy: 36.22
# Epoch 8, Episode 7, Train Loss: 17.79, Train Accuracy: 38.67
# Epoch 8, Episode 8, Train Loss: 19.21, Train Accuracy: 40.17
# Epoch 8, Episode 9, Train Loss: 18.36, Train Accuracy: 39.26
# Epoch 8, Episode 10, Train Loss: 18.12, Train Accuracy: 38.80
# Epoch 8, Episode 11, Train Loss: 17.63, Train Accuracy: 37.82
# Epoch 8, Episode 12, Train Loss: 18.23, Train Accuracy: 38.78
# Epoch 8, Episode 13, Train Loss: 18.57, Train Accuracy: 39.59
# Epoch 8, Episode 14, Train Loss: 18.49, Train Accuracy: 40.10
# Epoch 8, Episode 15, Train Loss: 18.95, Train Accuracy: 40.71
# Epoch 8, Episode 16, Train Loss: 18.47, Train Accuracy: 40.00
# Epoch 8, Episode 17, Train Loss: 18.25, Train Accuracy: 40.39
# Epoch 8, Episode 18, Train Loss: 17.88, Train Accuracy: 39.56
# Epoch 8, Episode 19, Train Loss: 18.01, Train Accuracy: 39.93
# Epoch 8, Episode 20, Train Loss: 18.23, Train Accuracy: 40.27
# Epoch 8, Episode 21, Train Loss: 17.97, Train Accuracy: 39.87
# Epoch 8, Episode 22, Train Loss: 17.87, Train Accuracy: 39.58
# Epoch 8, Episode 23, Train Loss: 17.68, Train Accuracy: 39.19
# Epoch 8, Episode 24, Train Loss: 17.58, Train Accuracy: 39.67
# Epoch 8, Episode 25, Train Loss: 17.35, Train Accuracy: 39.15
# Epoch 8, Episode 26, Train Loss: 17.11, Train Accuracy: 38.77
# Epoch 8, Episode 27, Train Loss: 17.11, Train Accuracy: 38.52
# Epoch 8, Episode 28, Train Loss: 17.29, Train Accuracy: 38.90
# Epoch 8, Episode 29, Train Loss: 17.25, Train Accuracy: 39.13
# Epoch 8, Episode 30, Train Loss: 17.21, Train Accuracy: 39.38
# Epoch 8, Episode 31, Train Loss: 17.42, Train Accuracy: 39.40
# Epoch 8, Episode 32, Train Loss: 17.75, Train Accuracy: 39.75
# Epoch 8, Episode 33, Train Loss: 18.02, Train Accuracy: 39.96
# Epoch 8, Episode 34, Train Loss: 18.03, Train Accuracy: 40.04
# Epoch 8, Episode 35, Train Loss: 17.96, Train Accuracy: 40.04
# Epoch 8, Episode 36, Train Loss: 17.97, Train Accuracy: 40.15
# Epoch 8, Episode 37, Train Loss: 17.96, Train Accuracy: 40.79
# Epoch 8, Episode 38, Train Loss: 17.82, Train Accuracy: 40.32
# Epoch 8, Episode 39, Train Loss: 17.80, Train Accuracy: 39.93
# Epoch 8, Episode 40, Train Loss: 17.91, Train Accuracy: 40.10
# Epoch 8, Episode 41, Train Loss: 17.89, Train Accuracy: 40.23
# Epoch 8, Episode 42, Train Loss: 17.86, Train Accuracy: 40.51
# Epoch 8, Episode 43, Train Loss: 17.71, Train Accuracy: 40.22
# Epoch 8, Episode 44, Train Loss: 17.82, Train Accuracy: 40.42
# Epoch 8, Episode 45, Train Loss: 17.84, Train Accuracy: 40.18
# Epoch 8, Episode 46, Train Loss: 17.73, Train Accuracy: 39.97
# Epoch 8, Episode 47, Train Loss: 17.98, Train Accuracy: 40.43
# Epoch 8, Episode 48, Train Loss: 18.09, Train Accuracy: 40.53
# Epoch 8, Episode 49, Train Loss: 18.09, Train Accuracy: 40.63
# Epoch 8, Episode 50, Train Loss: 17.99, Train Accuracy: 40.48
# Epoch 8, Episode 51, Train Loss: 18.02, Train Accuracy: 40.71
# Epoch 8, Episode 52, Train Loss: 17.92, Train Accuracy: 40.46
# Epoch 8, Episode 53, Train Loss: 18.01, Train Accuracy: 40.73
# Epoch 8, Episode 54, Train Loss: 18.15, Train Accuracy: 41.14
# Epoch 8, Episode 55, Train Loss: 18.17, Train Accuracy: 40.87
# ...
# Epoch 48, Episode 47, Train Loss: 32.60, Train Accuracy: 89.53
# Epoch 48, Episode 48, Train Loss: 32.72, Train Accuracy: 89.53
# Epoch 48, Episode 49, Train Loss: 32.85, Train Accuracy: 89.61
# Epoch 48, Episode 50, Train Loss: 32.82, Train Accuracy: 89.76
# Epoch 48, Episode 51, Train Loss: 32.68, Train Accuracy: 89.88
# Epoch 48, Episode 52, Train Loss: 32.62, Train Accuracy: 90.08
# Epoch 48, Episode 53, Train Loss: 32.46, Train Accuracy: 90.11
# Epoch 48, Episode 54, Train Loss: 32.43, Train Accuracy: 90.02
# Epoch 48, Episode 55, Train Loss: 32.24, Train Accuracy: 89.87
# Epoch 48, Episode 56, Train Loss: 32.24, Train Accuracy: 89.88
# Epoch 48, Episode 57, Train Loss: 32.21, Train Accuracy: 90.04
# Epoch 48, Episode 58, Train Loss: 32.30, Train Accuracy: 90.21
# Epoch 48, Episode 59, Train Loss: 32.45, Train Accuracy: 90.19
# Epoch 48, Episode 60, Train Loss: 32.53, Train Accuracy: 90.02
# Epoch 48, Episode 61, Train Loss: 32.67, Train Accuracy: 90.05
# Epoch 48, Episode 62, Train Loss: 32.71, Train Accuracy: 90.02
# Epoch 48, Episode 63, Train Loss: 32.54, Train Accuracy: 90.03
# Epoch 48, Episode 64, Train Loss: 32.56, Train Accuracy: 90.15
# Epoch 48, Episode 65, Train Loss: 32.50, Train Accuracy: 90.22
# Epoch 48, Episode 66, Train Loss: 32.51, Train Accuracy: 90.34
# Epoch 48, Episode 67, Train Loss: 32.35, Train Accuracy: 90.49
# Epoch 48, Episode 68, Train Loss: 32.24, Train Accuracy: 90.57
# Epoch 48, Episode 69, Train Loss: 32.37, Train Accuracy: 90.65
# Epoch 48, Episode 70, Train Loss: 32.35, Train Accuracy: 90.67
# Epoch 48, Episode 71, Train Loss: 32.45, Train Accuracy: 90.55
# Epoch 48, Episode 72, Train Loss: 32.47, Train Accuracy: 90.57
# Epoch 48, Episode 73, Train Loss: 32.53, Train Accuracy: 90.70
# Epoch 48, Episode 74, Train Loss: 32.54, Train Accuracy: 90.67
# Epoch 48, Episode 75, Train Loss: 32.65, Train Accuracy: 90.72
# Epoch 48, Episode 76, Train Loss: 32.74, Train Accuracy: 90.77
# Epoch 48, Episode 77, Train Loss: 32.83, Train Accuracy: 90.84
# Epoch 48, Episode 78, Train Loss: 32.72, Train Accuracy: 90.85
# Epoch 48, Episode 79, Train Loss: 32.68, Train Accuracy: 90.94
# Epoch 48, Episode 80, Train Loss: 32.75, Train Accuracy: 91.00
# Epoch 48, Episode 81, Train Loss: 32.82, Train Accuracy: 90.93
# Epoch 48, Episode 82, Train Loss: 32.76, Train Accuracy: 90.89
# Epoch 48, Episode 83, Train Loss: 32.72, Train Accuracy: 90.96
# Epoch 48, Episode 84, Train Loss: 32.59, Train Accuracy: 91.05
# Epoch 48, Episode 85, Train Loss: 32.59, Train Accuracy: 91.03
# Epoch 48, Episode 86, Train Loss: 32.60, Train Accuracy: 90.96
# Epoch 48, Episode 87, Train Loss: 32.61, Train Accuracy: 90.87
# Epoch 48, Episode 88, Train Loss: 32.59, Train Accuracy: 90.91
# Epoch 48, Episode 89, Train Loss: 32.59, Train Accuracy: 90.94
# Epoch 48, Episode 90, Train Loss: 32.67, Train Accuracy: 90.79
# Epoch 48, Episode 91, Train Loss: 32.59, Train Accuracy: 90.70
# Epoch 48, Episode 92, Train Loss: 32.63, Train Accuracy: 90.74
# Epoch 48, Episode 93, Train Loss: 32.59, Train Accuracy: 90.77
# Epoch 48, Episode 94, Train Loss: 32.62, Train Accuracy: 90.74
# Epoch 48, Episode 95, Train Loss: 32.55, Train Accuracy: 90.81
# Epoch 48, Episode 96, Train Loss: 32.45, Train Accuracy: 90.65
# Epoch 48, Episode 97, Train Loss: 32.43, Train Accuracy: 90.74
# Epoch 48, Episode 98, Train Loss: 32.44, Train Accuracy: 90.82
# Epoch 48, Episode 99, Train Loss: 32.45, Train Accuracy: 90.84
# Epoch 48, Episode 100, Train Loss: 32.41, Train Accuracy: 90.84
# Epoch 49, Episode 1, Train Loss: 27.85, Train Accuracy: 96.00
# Epoch 49, Episode 2, Train Loss: 30.82, Train Accuracy: 97.33
# Epoch 49, Episode 3, Train Loss: 29.58, Train Accuracy: 96.44
# Epoch 49, Episode 4, Train Loss: 29.35, Train Accuracy: 96.00
# Epoch 49, Episode 5, Train Loss: 31.41, Train Accuracy: 94.93
# Epoch 49, Episode 6, Train Loss: 30.39, Train Accuracy: 95.33
# Epoch 49, Episode 7, Train Loss: 31.59, Train Accuracy: 93.90
# Epoch 49, Episode 8, Train Loss: 32.71, Train Accuracy: 92.00
# Epoch 49, Episode 9, Train Loss: 32.90, Train Accuracy: 92.00
# Epoch 49, Episode 10, Train Loss: 33.08, Train Accuracy: 91.47
# Epoch 49, Episode 11, Train Loss: 33.36, Train Accuracy: 91.88
# Epoch 49, Episode 12, Train Loss: 33.23, Train Accuracy: 92.22
# Epoch 49, Episode 13, Train Loss: 33.49, Train Accuracy: 92.00
# Epoch 49, Episode 14, Train Loss: 33.58, Train Accuracy: 92.00
# Epoch 49, Episode 15, Train Loss: 33.34, Train Accuracy: 92.09
# Epoch 49, Episode 16, Train Loss: 33.03, Train Accuracy: 92.50
# Epoch 49, Episode 17, Train Loss: 33.09, Train Accuracy: 92.63
# Epoch 49, Episode 18, Train Loss: 33.29, Train Accuracy: 92.30
# Epoch 49, Episode 19, Train Loss: 32.78, Train Accuracy: 92.14
# Epoch 49, Episode 20, Train Loss: 32.69, Train Accuracy: 92.33
# Epoch 49, Episode 21, Train Loss: 32.79, Train Accuracy: 92.06
# Epoch 49, Episode 22, Train Loss: 32.84, Train Accuracy: 91.76
# Epoch 49, Episode 23, Train Loss: 32.60, Train Accuracy: 92.00
# Epoch 49, Episode 24, Train Loss: 32.40, Train Accuracy: 91.72
# Epoch 49, Episode 25, Train Loss: 32.31, Train Accuracy: 91.84
# Epoch 49, Episode 26, Train Loss: 32.15, Train Accuracy: 91.64
# Epoch 49, Episode 27, Train Loss: 32.36, Train Accuracy: 91.65
# Epoch 49, Episode 28, Train Loss: 32.05, Train Accuracy: 91.90
# Epoch 49, Episode 29, Train Loss: 32.03, Train Accuracy: 91.68
# Epoch 49, Episode 30, Train Loss: 32.01, Train Accuracy: 91.38
# Epoch 49, Episode 31, Train Loss: 32.07, Train Accuracy: 91.57
# Epoch 49, Episode 32, Train Loss: 31.93, Train Accuracy: 91.75
# Epoch 49, Episode 33, Train Loss: 32.06, Train Accuracy: 91.76
# Epoch 49, Episode 34, Train Loss: 32.07, Train Accuracy: 91.84
# Epoch 49, Episode 35, Train Loss: 32.05, Train Accuracy: 92.08
# Epoch 49, Episode 36, Train Loss: 31.95, Train Accuracy: 91.96
# Epoch 49, Episode 37, Train Loss: 31.91, Train Accuracy: 92.11
# Epoch 49, Episode 38, Train Loss: 32.10, Train Accuracy: 91.86
# Epoch 49, Episode 39, Train Loss: 31.88, Train Accuracy: 91.83
# Epoch 49, Episode 40, Train Loss: 31.61, Train Accuracy: 91.87
# Epoch 49, Episode 41, Train Loss: 31.72, Train Accuracy: 92.03
# Epoch 49, Episode 42, Train Loss: 31.70, Train Accuracy: 92.22
# Epoch 49, Episode 43, Train Loss: 31.67, Train Accuracy: 91.81
# Epoch 49, Episode 44, Train Loss: 31.66, Train Accuracy: 91.67
# Epoch 49, Episode 45, Train Loss: 31.50, Train Accuracy: 91.35
# Epoch 49, Episode 46, Train Loss: 31.56, Train Accuracy: 91.16
# Epoch 49, Episode 47, Train Loss: 31.63, Train Accuracy: 91.26
# Epoch 49, Episode 48, Train Loss: 31.74, Train Accuracy: 91.19
# Epoch 49, Episode 49, Train Loss: 31.75, Train Accuracy: 91.29
# Epoch 49, Episode 50, Train Loss: 31.89, Train Accuracy: 91.12
# Epoch 49, Episode 51, Train Loss: 31.87, Train Accuracy: 90.93
# Epoch 49, Episode 52, Train Loss: 31.75, Train Accuracy: 90.92
# Epoch 49, Episode 53, Train Loss: 31.74, Train Accuracy: 90.87
# Epoch 49, Episode 54, Train Loss: 31.73, Train Accuracy: 91.01
# Epoch 49, Episode 55, Train Loss: 31.85, Train Accuracy: 90.86
# Epoch 49, Episode 56, Train Loss: 31.90, Train Accuracy: 90.93
# Epoch 49, Episode 57, Train Loss: 31.83, Train Accuracy: 90.99
# Epoch 49, Episode 58, Train Loss: 31.77, Train Accuracy: 90.97
# Epoch 49, Episode 59, Train Loss: 31.79, Train Accuracy: 90.89
# Epoch 49, Episode 60, Train Loss: 31.79, Train Accuracy: 90.98
# Epoch 49, Episode 61, Train Loss: 31.73, Train Accuracy: 91.04
# Epoch 49, Episode 62, Train Loss: 31.78, Train Accuracy: 90.92
# Epoch 49, Episode 63, Train Loss: 31.75, Train Accuracy: 90.96
# Epoch 49, Episode 64, Train Loss: 31.72, Train Accuracy: 91.00
# Epoch 49, Episode 65, Train Loss: 31.73, Train Accuracy: 91.10
# Epoch 49, Episode 66, Train Loss: 31.75, Train Accuracy: 91.09
# Epoch 49, Episode 67, Train Loss: 31.77, Train Accuracy: 91.12
# Epoch 49, Episode 68, Train Loss: 31.78, Train Accuracy: 91.25
# Epoch 49, Episode 69, Train Loss: 31.73, Train Accuracy: 91.25
# Epoch 49, Episode 70, Train Loss: 31.65, Train Accuracy: 91.22
# Epoch 49, Episode 71, Train Loss: 31.75, Train Accuracy: 91.31
# Epoch 49, Episode 72, Train Loss: 31.66, Train Accuracy: 91.35
# Epoch 49, Episode 73, Train Loss: 31.62, Train Accuracy: 91.31
# Epoch 49, Episode 74, Train Loss: 31.64, Train Accuracy: 91.37
# Epoch 49, Episode 75, Train Loss: 31.52, Train Accuracy: 91.47
# Epoch 49, Episode 76, Train Loss: 31.50, Train Accuracy: 91.54
# Epoch 49, Episode 77, Train Loss: 31.46, Train Accuracy: 91.53
# Epoch 49, Episode 78, Train Loss: 31.44, Train Accuracy: 91.32
# Epoch 49, Episode 79, Train Loss: 31.36, Train Accuracy: 91.36
# Epoch 49, Episode 80, Train Loss: 31.35, Train Accuracy: 91.45
# Epoch 49, Episode 81, Train Loss: 31.26, Train Accuracy: 91.39
# Epoch 49, Episode 82, Train Loss: 31.25, Train Accuracy: 91.32
# Epoch 49, Episode 83, Train Loss: 31.28, Train Accuracy: 91.31
# Epoch 49, Episode 84, Train Loss: 31.33, Train Accuracy: 91.38
# Epoch 49, Episode 85, Train Loss: 31.36, Train Accuracy: 91.47
# Epoch 49, Episode 86, Train Loss: 31.39, Train Accuracy: 91.46
# Epoch 49, Episode 87, Train Loss: 31.54, Train Accuracy: 91.43
# Epoch 49, Episode 88, Train Loss: 31.61, Train Accuracy: 91.45
# Epoch 49, Episode 89, Train Loss: 31.72, Train Accuracy: 91.28
# Epoch 49, Episode 90, Train Loss: 31.69, Train Accuracy: 91.36
# Epoch 49, Episode 91, Train Loss: 31.69, Train Accuracy: 91.41
# Epoch 49, Episode 92, Train Loss: 31.80, Train Accuracy: 91.39
# Epoch 49, Episode 93, Train Loss: 31.87, Train Accuracy: 91.37
# Epoch 49, Episode 94, Train Loss: 31.90, Train Accuracy: 91.45
# Epoch 49, Episode 95, Train Loss: 31.80, Train Accuracy: 91.52
# Epoch 49, Episode 96, Train Loss: 31.86, Train Accuracy: 91.44
# Epoch 49, Episode 97, Train Loss: 31.79, Train Accuracy: 91.53
# Epoch 49, Episode 98, Train Loss: 31.77, Train Accuracy: 91.54
# Epoch 49, Episode 99, Train Loss: 31.78, Train Accuracy: 91.62
# Epoch 49, Episode 100, Train Loss: 31.73, Train Accuracy: 91.67
# Epoch 50, Episode 1, Train Loss: 27.46, Train Accuracy: 97.33
# Epoch 50, Episode 2, Train Loss: 29.61, Train Accuracy: 96.00
# Epoch 50, Episode 3, Train Loss: 31.44, Train Accuracy: 96.44
# Epoch 50, Episode 4, Train Loss: 32.53, Train Accuracy: 96.00
# Epoch 50, Episode 5, Train Loss: 32.13, Train Accuracy: 96.27
# Epoch 50, Episode 6, Train Loss: 32.91, Train Accuracy: 96.00
# Epoch 50, Episode 7, Train Loss: 33.16, Train Accuracy: 95.81
# Epoch 50, Episode 8, Train Loss: 33.23, Train Accuracy: 95.33
# Epoch 50, Episode 9, Train Loss: 34.16, Train Accuracy: 94.96
# Epoch 50, Episode 10, Train Loss: 33.30, Train Accuracy: 95.47
# Epoch 50, Episode 11, Train Loss: 33.51, Train Accuracy: 94.18
# Epoch 50, Episode 12, Train Loss: 32.36, Train Accuracy: 94.67
# Epoch 50, Episode 13, Train Loss: 32.57, Train Accuracy: 94.26
# Epoch 50, Episode 14, Train Loss: 32.37, Train Accuracy: 94.10
# Epoch 50, Episode 15, Train Loss: 32.15, Train Accuracy: 94.31
# Epoch 50, Episode 16, Train Loss: 31.53, Train Accuracy: 94.58
# Epoch 50, Episode 17, Train Loss: 31.36, Train Accuracy: 94.12
# Epoch 50, Episode 18, Train Loss: 30.90, Train Accuracy: 94.44
# Epoch 50, Episode 19, Train Loss: 31.01, Train Accuracy: 94.39
# Epoch 50, Episode 20, Train Loss: 31.20, Train Accuracy: 94.07
# Epoch 50, Episode 21, Train Loss: 30.85, Train Accuracy: 94.35
# Epoch 50, Episode 22, Train Loss: 30.78, Train Accuracy: 94.00
# Epoch 50, Episode 23, Train Loss: 30.32, Train Accuracy: 94.20
# Epoch 50, Episode 24, Train Loss: 30.02, Train Accuracy: 94.39
# Epoch 50, Episode 25, Train Loss: 30.28, Train Accuracy: 94.08
# Epoch 50, Episode 26, Train Loss: 29.62, Train Accuracy: 94.21
# Epoch 50, Episode 27, Train Loss: 29.43, Train Accuracy: 94.07
# Epoch 50, Episode 28, Train Loss: 29.26, Train Accuracy: 94.05
# Epoch 50, Episode 29, Train Loss: 29.49, Train Accuracy: 93.56
# Epoch 50, Episode 30, Train Loss: 29.70, Train Accuracy: 93.60
# Epoch 50, Episode 31, Train Loss: 29.62, Train Accuracy: 93.42
# Epoch 50, Episode 32, Train Loss: 29.96, Train Accuracy: 93.33
# Epoch 50, Episode 33, Train Loss: 30.07, Train Accuracy: 93.41
# Epoch 50, Episode 34, Train Loss: 30.05, Train Accuracy: 93.02
# Epoch 50, Episode 35, Train Loss: 29.91, Train Accuracy: 93.18
# Epoch 50, Episode 36, Train Loss: 29.79, Train Accuracy: 93.19
# Epoch 50, Episode 37, Train Loss: 29.82, Train Accuracy: 92.83
# Epoch 50, Episode 38, Train Loss: 29.88, Train Accuracy: 92.88
# Epoch 50, Episode 39, Train Loss: 29.81, Train Accuracy: 92.82
# Epoch 50, Episode 40, Train Loss: 29.75, Train Accuracy: 92.83
# Epoch 50, Episode 41, Train Loss: 29.64, Train Accuracy: 92.91
# Epoch 50, Episode 42, Train Loss: 29.80, Train Accuracy: 92.70
# Epoch 50, Episode 43, Train Loss: 29.82, Train Accuracy: 92.68
# Epoch 50, Episode 44, Train Loss: 29.78, Train Accuracy: 92.79
# Epoch 50, Episode 45, Train Loss: 29.66, Train Accuracy: 92.77
# Epoch 50, Episode 46, Train Loss: 29.68, Train Accuracy: 92.52
# Epoch 50, Episode 47, Train Loss: 29.80, Train Accuracy: 92.54
# Epoch 50, Episode 48, Train Loss: 29.87, Train Accuracy: 92.58
# Epoch 50, Episode 49, Train Loss: 29.76, Train Accuracy: 92.73
# Epoch 50, Episode 50, Train Loss: 29.79, Train Accuracy: 92.83
# Epoch 50, Episode 51, Train Loss: 29.63, Train Accuracy: 92.94
# Epoch 50, Episode 52, Train Loss: 29.76, Train Accuracy: 92.95
# Epoch 50, Episode 53, Train Loss: 29.81, Train Accuracy: 92.86
# Epoch 50, Episode 54, Train Loss: 29.83, Train Accuracy: 92.69
# Epoch 50, Episode 55, Train Loss: 29.81, Train Accuracy: 92.65
# Epoch 50, Episode 56, Train Loss: 29.98, Train Accuracy: 92.62
# Epoch 50, Episode 57, Train Loss: 29.96, Train Accuracy: 92.54
# Epoch 50, Episode 58, Train Loss: 29.94, Train Accuracy: 92.57
# Epoch 50, Episode 59, Train Loss: 29.88, Train Accuracy: 92.54
# Epoch 50, Episode 60, Train Loss: 29.90, Train Accuracy: 92.40
# Epoch 50, Episode 61, Train Loss: 30.13, Train Accuracy: 92.44
# Epoch 50, Episode 62, Train Loss: 30.32, Train Accuracy: 92.45
# Epoch 50, Episode 63, Train Loss: 30.27, Train Accuracy: 92.55
# Epoch 50, Episode 64, Train Loss: 30.27, Train Accuracy: 92.60
# Epoch 50, Episode 65, Train Loss: 30.39, Train Accuracy: 92.57
# Epoch 50, Episode 66, Train Loss: 30.41, Train Accuracy: 92.61
# Epoch 50, Episode 67, Train Loss: 30.35, Train Accuracy: 92.52
# Epoch 50, Episode 68, Train Loss: 30.39, Train Accuracy: 92.55
# Epoch 50, Episode 69, Train Loss: 30.38, Train Accuracy: 92.62
# Epoch 50, Episode 70, Train Loss: 30.47, Train Accuracy: 92.50
# Epoch 50, Episode 71, Train Loss: 30.42, Train Accuracy: 92.56
# Epoch 50, Episode 72, Train Loss: 30.38, Train Accuracy: 92.67
# Epoch 50, Episode 73, Train Loss: 30.44, Train Accuracy: 92.69
# Epoch 50, Episode 74, Train Loss: 30.37, Train Accuracy: 92.70
# Epoch 50, Episode 75, Train Loss: 30.50, Train Accuracy: 92.68
# Epoch 50, Episode 76, Train Loss: 30.52, Train Accuracy: 92.65
# Epoch 50, Episode 77, Train Loss: 30.45, Train Accuracy: 92.50
# Epoch 50, Episode 78, Train Loss: 30.34, Train Accuracy: 92.60
# Epoch 50, Episode 79, Train Loss: 30.48, Train Accuracy: 92.61
# Epoch 50, Episode 80, Train Loss: 30.49, Train Accuracy: 92.67
# Epoch 50, Episode 81, Train Loss: 30.56, Train Accuracy: 92.64
# Epoch 50, Episode 82, Train Loss: 30.58, Train Accuracy: 92.60
# Epoch 50, Episode 83, Train Loss: 30.60, Train Accuracy: 92.63
# Epoch 50, Episode 84, Train Loss: 30.60, Train Accuracy: 92.70
# Epoch 50, Episode 85, Train Loss: 30.64, Train Accuracy: 92.60
# Epoch 50, Episode 86, Train Loss: 30.75, Train Accuracy: 92.64
# Epoch 50, Episode 87, Train Loss: 30.78, Train Accuracy: 92.67
# Epoch 50, Episode 88, Train Loss: 30.66, Train Accuracy: 92.65
# Epoch 50, Episode 89, Train Loss: 30.76, Train Accuracy: 92.60
# Epoch 50, Episode 90, Train Loss: 30.80, Train Accuracy: 92.52
# Epoch 50, Episode 91, Train Loss: 30.72, Train Accuracy: 92.60
# Epoch 50, Episode 92, Train Loss: 30.82, Train Accuracy: 92.59
# Epoch 50, Episode 93, Train Loss: 30.89, Train Accuracy: 92.60
# Epoch 50, Episode 94, Train Loss: 30.92, Train Accuracy: 92.52
# Epoch 50, Episode 95, Train Loss: 30.98, Train Accuracy: 92.31
# Epoch 50, Episode 96, Train Loss: 30.95, Train Accuracy: 92.37
# Epoch 50, Episode 97, Train Loss: 30.98, Train Accuracy: 92.38
# Epoch 50, Episode 98, Train Loss: 30.93, Train Accuracy: 92.39
# Epoch 50, Episode 99, Train Loss: 30.88, Train Accuracy: 92.34
# Epoch 50, Episode 100, Train Loss: 30.86, Train Accuracy: 92.20

# %% [markdown]
# **Tuning_5**

# %%
tune_set_5 = [[] for i in range(6)]
for j in range(6) :
  tune_set_5[j] = test_patches_class[j][:5,:,:,:,:]   # for each class first 5 samples taken
std_tune_5 = []

# %%
def tune_episode(tune_set,tC,tK,tN,test_class_labels) :
  selected_classes = np.random.choice(test_class_labels,tC,replace=False)
  support_labels  = list(selected_classes)
  query_labels = []
  support_patches = []
  query_patches = []
  for x in selected_classes :
    y = test_class_labels.index(x)
    np.random.shuffle(tune_set[y])    
    support_imgs = tune_set[y][:tK,:,:,:,:]    #Support 1, Query 4
    query_imgs = tune_set[y][tK:5,:,:,:,:]
    support_patches.extend(support_imgs)
    query_patches.extend(query_imgs)
    for i in range(tN) :
      query_labels.append(x)
  temp1 = list(zip(query_patches, query_labels)) 
  random.shuffle(temp1) 
  query_patches, query_labels = zip(*temp1)
  query_patches = tf.convert_to_tensor(np.reshape(np.asarray(query_patches),(tC*tN,im_height,im_width,im_depth,1)),dtype=tf.float32)
  support_patches = tf.convert_to_tensor(np.reshape(np.asarray(support_patches),(tC*tK,im_height,im_width,im_depth,1)),dtype=tf.float32)
  return query_patches, support_patches, query_labels, support_labels

# %%
query_patches, support_patches, query_labels, support_labels = tune_episode(tune_set_5,4,1,4,test_class_labels)

# %%
# Metrics to gather
tune_loss = tf.metrics.Mean(name='tune_loss')
tune_acc = tf.metrics.Mean(name='tune_accuracy')

def tune_step(support, query, support_labels, query_labels, K, C, N):
    # Forward & update gradients
    with tf.GradientTape() as tape:
        loss, mean_accuracy, mean_predictions = ProtoModel(support, query, support_labels, query_labels, K, C, N,n_times,training=True)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    # Log loss and accuracy for step
    tune_loss(loss)
    tune_acc(mean_accuracy)

# %%
checkpoint_dir1 = '/content/drive/My Drive/Research/SAMPLE_CODE_TF2_Keras/Inprogress/Hyperspectral_Classification/Training checkpoints/IP/5_shot_ckpts/New_train_5_way_ip_25_128/Tune'
checkpoint_prefix1 = os.path.join(checkpoint_dir1, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 ProtoModel = ProtoModel)

# %%
n_episodes = 100
temp_list = []
std_tune_5 = []
for epoch in range(41): 
    tune_loss.reset_states()  
    tune_acc.reset_states()    
    for epi in range(n_episodes+1): 
        tquery_patches, tsupport_patches, query_labels, support_labels = tune_episode(tune_set_5,3,1,4,test_class_labels)    
        tune_step(tsupport_patches, tquery_patches,support_labels, query_labels, 1, 3, 4)      
        
    template = 'Epoch {}, Tune Loss: {:.2f}, Tune Accuracy: {:.2f}'
    print(template.format(epoch+1,tune_loss.result(),tune_acc.result()*100))
    if (epoch+1)%5 == 0 :
      checkpoint.save(file_prefix = checkpoint_prefix1)
# Out:
# Epoch 1, Tune Loss: 5.01, Tune Accuracy: 99.17
# Epoch 2, Tune Loss: 3.02, Tune Accuracy: 99.92
# Epoch 3, Tune Loss: 2.26, Tune Accuracy: 100.00
# Epoch 4, Tune Loss: 2.20, Tune Accuracy: 100.00
# Epoch 5, Tune Loss: 1.55, Tune Accuracy: 100.00
# Epoch 6, Tune Loss: 2.07, Tune Accuracy: 100.00
# Epoch 7, Tune Loss: 1.60, Tune Accuracy: 100.00
# Epoch 8, Tune Loss: 1.03, Tune Accuracy: 100.00
# Epoch 9, Tune Loss: 0.97, Tune Accuracy: 100.00
# Epoch 10, Tune Loss: 0.85, Tune Accuracy: 100.00
# Epoch 11, Tune Loss: 1.05, Tune Accuracy: 100.00
# Epoch 12, Tune Loss: 0.86, Tune Accuracy: 100.00
# Epoch 13, Tune Loss: 0.60, Tune Accuracy: 100.00
# Epoch 14, Tune Loss: 0.76, Tune Accuracy: 100.00
# Epoch 15, Tune Loss: 0.77, Tune Accuracy: 100.00
# Epoch 16, Tune Loss: 0.83, Tune Accuracy: 100.00
# Epoch 17, Tune Loss: 0.74, Tune Accuracy: 100.00
# Epoch 18, Tune Loss: 0.74, Tune Accuracy: 100.00
# Epoch 19, Tune Loss: 0.56, Tune Accuracy: 100.00
# Epoch 20, Tune Loss: 0.51, Tune Accuracy: 100.00
# Epoch 21, Tune Loss: 0.69, Tune Accuracy: 100.00
# Epoch 22, Tune Loss: 0.65, Tune Accuracy: 100.00
# Epoch 23, Tune Loss: 0.32, Tune Accuracy: 100.00
# Epoch 24, Tune Loss: 0.52, Tune Accuracy: 100.00
# Epoch 25, Tune Loss: 0.52, Tune Accuracy: 100.00
# Epoch 26, Tune Loss: 0.40, Tune Accuracy: 100.00
# Epoch 27, Tune Loss: 0.38, Tune Accuracy: 100.00
# Epoch 28, Tune Loss: 0.31, Tune Accuracy: 100.00
# Epoch 29, Tune Loss: 0.33, Tune Accuracy: 100.00
# Epoch 30, Tune Loss: 0.38, Tune Accuracy: 100.00
# Epoch 31, Tune Loss: 0.33, Tune Accuracy: 100.00
# Epoch 32, Tune Loss: 0.30, Tune Accuracy: 100.00
# Epoch 33, Tune Loss: 0.39, Tune Accuracy: 100.00
# Epoch 34, Tune Loss: 0.29, Tune Accuracy: 100.00
# Epoch 35, Tune Loss: 0.37, Tune Accuracy: 100.00
# Epoch 36, Tune Loss: 0.35, Tune Accuracy: 100.00
# Epoch 37, Tune Loss: 0.35, Tune Accuracy: 100.00
# Epoch 38, Tune Loss: 0.21, Tune Accuracy: 100.00
# Epoch 39, Tune Loss: 0.38, Tune Accuracy: 100.00
# Epoch 40, Tune Loss: 0.15, Tune Accuracy: 100.00
# Epoch 41, Tune Loss: 0.38, Tune Accuracy: 100.00

# %%
def test_episode(test_patches_class,test_class_labels,test_C,test_K,i,f) :
  selected_classes = test_class_labels[i:f]   # [1, 2, 3, 4, 5, 6, 7, 8]
  support_labels = list(selected_classes)
  query_labels = []
  support_patches = []
  query_patches = []
  for x in selected_classes :
    y = test_class_labels.index(x)
    support_imgs = test_patches_class[y][:test_K,:,:,:,:]
    query_imgs = test_patches_class[y][test_K:,:,:,:,:]
    support_patches.extend(support_imgs)
    query_patches.extend(query_imgs)
    for i in range(query_imgs.shape[0]) :
      query_labels.append(x)
  temp1 = list(zip(query_patches, query_labels)) 
  random.shuffle(temp1) 
  query_patches, query_labels = zip(*temp1)
  x = len(query_labels)
  query_patches = tf.convert_to_tensor(np.reshape(np.asarray(query_patches),(x,im_height,im_width,im_depth,1)),dtype=tf.float32)
  support_patches = tf.convert_to_tensor(np.reshape(np.asarray(support_patches),(test_C*test_K,im_height,im_width,im_depth,1)),dtype=tf.float32)
  return query_patches, support_patches, query_labels, support_labels,x

# %%
query_patches, support_patches, query_labels, support_labels,x = test_episode(test_patches_class,test_class_labels,3,5,0,3)

# %%
# Metrics to gather
test_loss = tf.metrics.Mean(name='test_loss')
test_acc = tf.metrics.Mean(name='test_accuracy')
def test_step(support, query, support_labels, query_labels, K, C, y):
    loss, mc_predictions, mean_accuracy, classwise_mean_acc, y = ProtoModel(support, query, support_labels, query_labels, K, C, y,n_times,training=False)
    return loss, mc_predictions, mean_accuracy, classwise_mean_acc, y

# %%
for epoch in range(1): #1000
    test_loss.reset_states()  
    test_acc.reset_states()        
    tquery_patches1, tsupport_patches1, query_labels1, support_labels1, x1 = test_episode(test_patches_class,test_class_labels,3,5,0,3)    
    loss1, mc_predictions1, mean_accuracy1, classwise_mean_acc1, y1 = test_step(tsupport_patches1, tquery_patches1,support_labels1, query_labels1, 5, 3, x1/3)      
    print('OA1',mean_accuracy1)
# Class-wise Accuracy
    for i in range(tC) :
      print('class',i+1,classwise_mean_acc1[i])
    print('loss',loss1)
    tquery_patches2, tsupport_patches2, query_labels2, support_labels2, x2 = test_episode(test_patches_class,test_class_labels,3,5,3,6)    
    loss2, mc_predictions2, mean_accuracy2, classwise_mean_acc2, y2 = test_step(tsupport_patches2, tquery_patches2,support_labels2, query_labels2, 5, 3, x2/3)
    print('OA2',mean_accuracy2) 
# Class-wise Accuracy
    for i in range(tC) :
      print('class',i+4,classwise_mean_acc2[i])
    print('loss',loss2)
# Out:
# OA1 tf.Tensor(0.9290541, shape=(), dtype=float32)
# class 1 [0.5121951219512195]
# class 2 [0.9956896551724138]
# class 3 [1.0]
# loss tf.Tensor(34.419327, shape=(), dtype=float32)
# OA2 tf.Tensor(0.76567656, shape=(), dtype=float32)
# class 4 [1.0]
# class 5 [0.65]
# class 6 [0.9886363636363636]
# loss tf.Tensor(63.02265, shape=(), dtype=float32)

# %% [markdown]
# **Overall Accuracy**

# %%
mean_predictions1 =  tf.reduce_mean(mc_predictions1,axis=0)
mean_predictions2 =  tf.reduce_mean(mc_predictions2,axis=0)
overall_predictions = tf.concat([mean_predictions1,mean_predictions2],axis=0)
overall_true_labels = tf.concat([y1,y2],axis=0)
correct_pred = tf.cast(tf.equal(                                             # accuracy for the current pass
            tf.cast(tf.argmax(overall_predictions, axis=-1), tf.int32), 
            tf.cast(tf.argmax(overall_true_labels,axis=-1), tf.int32)), tf.float32)
o_acc = tf.reduce_mean(correct_pred) 
print("Overall accuracy:",o_acc)
# Out:
# Overall accuracy: tf.Tensor(0.8464107, shape=(), dtype=float32)

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
mean_predictions1 =  tf.reduce_mean(mc_predictions1,axis=0)
cm_pred1 = tf.argmax(mean_predictions1, axis=-1)
mean_predictions2 =  tf.reduce_mean(mc_predictions2,axis=0)
cm_pred2 = tf.argmax(mean_predictions2, axis=-1) + 3
overall_predictions = tf.concat([cm_pred1,cm_pred2],axis=0)
cm_true1 = tf.argmax(y1,axis=-1)
cm_true2 = tf.argmax(y2,axis=-1) + 3
overall_true_labels = tf.concat([cm_true1,cm_true2],axis=0)
results = confusion_matrix(overall_true_labels,overall_predictions) 
print ('Confusion Matrix :')
print(results) 
print ('Report : ')
print (classification_report(overall_true_labels, overall_predictions))
# Out:
# Confusion Matrix :
# [[ 21   0  20   0   0   0]
#  [  1 231   0   0   0   0]
#  [  0   0  23   0   0   0]
#  [  0   0   0  15   0   0]
#  [  0   0   0  70 130   0]
#  [  0   0   0   0   1  87]]
# Report :
#               precision    recall  f1-score   support
#
#            0       0.95      0.51      0.67        41
#            1       1.00      1.00      1.00       232
#            2       0.53      1.00      0.70        23
#            3       0.18      1.00      0.30        15
#            4       0.99      0.65      0.79       200
#            5       1.00      0.99      0.99        88
#
#     accuracy                           0.85       599
#    macro avg       0.78      0.86      0.74       599
# weighted avg       0.96      0.85      0.87       599

# %% [markdown]
# **Kappa Accuracy**

# %%
import sklearn
sklearn.metrics.cohen_kappa_score(overall_true_labels, overall_predictions)
# Out:
# 0.7945165127317879
